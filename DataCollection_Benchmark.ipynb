# %% [markdown]
# <a href="https://colab.research.google.com/github/JuneHou/BirdSpeciesCNN/blob/main/DataCollection_Benchmark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

import os
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision import models
from torch.utils.data import random_split
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn.functional as F
from torchsummary import summary

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Appendix: Data Collection

# %% [markdown]
# - Setup path of train, test and valid file

# %%
train_dir = '/content/drive/MyDrive/NEU/DataMining/Project/train'
test_dir = '/content/drive/MyDrive/NEU/DataMining/Project/test'
val_dir = '/content/drive/MyDrive/NEU/DataMining/Project/valid'

# %% [markdown]
# - All images has dimension in 224 X 224 X 3, in which the 3 represents RGB images. The input dimension 224 x 224 is same as the model required. Data is normalized while transform to pytorch datasets.

# %%
transformations = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_data = datasets.ImageFolder(root=train_dir, transform=transformations)
test_data = datasets.ImageFolder(root=test_dir, transform=transformations)
valid_data = datasets.ImageFolder(root=val_dir, transform=transformations)

# %% [markdown]
# - The class_dict file shows the images and the classes it belongs to. The classes will used in the test model.

# %%
class_dict = pd.read_csv('/content/drive/MyDrive/NEU/DataMining/Project/class_dict.csv')
classes = list(class_dict['class'])
print(len(classes))
# Out:
# 350

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 16

# %%
# obtain training indices that will be used for validation
num_train, num_valid = len(train_data), len(valid_data)
train_index, valid_index = list(range(num_train)), list(range(num_valid))
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_index)
valid_sampler = SubsetRandomSampler(valid_index)
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size,
                                           sampler = train_sampler, num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size = batch_size,
                                          sampler = valid_sampler, num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size,
                                         num_workers = num_workers)

# %% [markdown]
# > Train Test Setup

# %%
def train (n_epoch, base_model, train_loader, optimizer, criterion, valid_loader):
  for epoch in range(n_epoch):  # loop over the dataset multiple times

    print('Epoch: ', epoch+1)
    class_correct = list(0. for i in range(350))
    class_total = list(0. for i in range(350))
    
    train_loss = 0
    valid_loss = 0
    
    base_model.train()
    for images, labels in train_loader:
        
        images = images.to(device)
        
        #Reset Grads
        optimizer.zero_grad()
        
        #Forward ->
        outputs = base_model(images).to("cpu")
        
        #Calculate Loss & Backward, Update Weights (Step)
        loss = criterion(outputs, labels)
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        train_loss += loss.item() * images.size(0)
    
    
    #Validation
    base_model.eval()
    for images, labels in valid_loader:
        
        images = images.to(device)
        
        #Forward ->
        preds = base_model(images).to("cpu")
        
        #Calculate Loss
        loss = criterion(preds, labels)
        valid_loss += loss.item() * images.size(0)
        # convert output probabilities to predicted class
        _, pred = torch.max(preds, 1)

        # compare predictions to true label
        correct = np.squeeze(pred.eq(labels.data.view_as(pred)))

        # calculate test accuracy for each object class
        for i in range(len(labels)):
            label = labels.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1

    print('\nValid Accuracy: %2d%%' % 
          (100. * np.sum(class_correct) / np.sum(class_total)))
    
    
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)
    
    #Print Epoch Statistics
    print("Train Loss = {}".format(round(train_loss, 4)))
    print("Valid Loss = {}".format(round(valid_loss, 4)))

# %%
def test (classes, base_model, test_loader, criterion):
  # initialize lists to monitor test loss and accuracy
  test_loss = 0.0
  class_correct = list(0. for i in range(len(classes)))
  class_total = list(0. for i in range(len(classes)))
  base_model.eval() # prep model for evaluation

  for data, target in test_loader:

      data = data.to(device)

      # forward pass: compute predicted outputs by passing inputs to the model
      output = base_model(data).to("cpu")
      # calculate the loss
      loss = criterion(output, target)
      # update test loss 
      test_loss += loss.item()*data.size(0)

      # convert output probabilities to predicted class
      _, pred = torch.max(output, 1)

      # compare predictions to true label
      correct = np.squeeze(pred.eq(target.data.view_as(pred)))

      # calculate test accuracy for each object class
      for i in range(len(target)):
          label = target.data[i]
          class_correct[label] += correct[i].item()
          class_total[label] += 1
        
  for i in range(len(classes)):
      if class_total[i] > 0:
          print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
              classes[i], 100 * class_correct[i] / class_total[i],
              np.sum(class_correct[i]), np.sum(class_total[i])))
      else:
          print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

  # calculate and print avg test loss
  test_loss = test_loss/len(test_loader.sampler)
  print('Test Loss: {:.6f}\n'.format(test_loss))
  print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
      100. * np.sum(class_correct) / np.sum(class_total),
      np.sum(class_correct), np.sum(class_total)))

# %% [markdown]
# > Model Setup

# %% [markdown]
# - The weight will not been updated in all layers except the fc layer. The fc layer as the output layer has the input dimension same as the pre-trained model, because both use 224 x 224 image, and the output dimension is the length of the classes (350).
# - To improve the speed, model is trained in the GPU.
# - The Criterion is Cross Entropy
# - The optimizer is Adam optimizer with learning rate equals 0.001.
# - Both model trained in 10 epoches.

# %% [markdown]
# # Benchmark Model -- VGG 19

# %% [markdown]
# VGG network is build based on the AlexNet, which published in 2012, and the name is the abbreviation of the group named as Visual Geometry Group at Oxford’s. VGG replaced the 11x11 and 5x5 filters with a stack of 3x3 filters layer. This is based on the finding of ZfNet, which was a frontline network of 2013-ILSVRC competition, suggested that small size filters can improve the performance of the CNNs. Two most famous models are: VGG-16, with 16 CNN layers and 3 fully connected layers; VGG-19, with 19 CNN layers and 3 fully connected layers.

# %%
from torchvision import models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model = models.vgg19(pretrained=True)

# turn training false for all layers, other than fc layer
for param in base_model.parameters():
    param.requires_grad = False
    
base_model.classifier
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %% [markdown]
# - Modify the 2nd fully connected layer from (4096, 4096) to (4096, 2048)
# - Modify the output layer with dimension same as number of classes (350)

# %%
base_model.classifier = nn.Sequential(
    nn.Linear(25088, 4096),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(4096, 2048),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(2048, len(classes))
    )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model = base_model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(base_model.parameters(), lr = 0.001)

# %% [markdown]
# - The architecture of the neural network is shown below

# %%
summary(base_model, (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 2048]       8,390,656
#              ReLU-43                 [-1, 2048]               0
#           Dropout-44                 [-1, 2048]               0
#            Linear-45                  [-1, 350]         717,150
# ================================================================
# Total params: 131,896,734
# Trainable params: 111,872,350
# Non-trainable params: 20,024,384
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.64
# Params size (MB): 503.15
# Estimated Total Size (MB): 742.36
# ----------------------------------------------------------------

# %%
train(10, base_model, train_loader, optimizer, criterion, valid_loader)
# Out:
# Epoch:  1
#
# Valid Accuracy:  2%
# Train Loss = 5.8404
# Valid Loss = 5.4765
# Epoch:  2
#
# Valid Accuracy:  2%
# Train Loss = 5.6864
# Valid Loss = 5.39
# Epoch:  3
#
# Valid Accuracy:  2%
# Train Loss = 5.6858
# Valid Loss = 5.382
# Epoch:  4
#
# Valid Accuracy:  2%
# Train Loss = 5.6977
# Valid Loss = 5.4755
# Epoch:  5
#
# Valid Accuracy:  1%
# Train Loss = 5.7436
# Valid Loss = 5.5864
# Epoch:  6
#
# Valid Accuracy:  1%
# Train Loss = 5.7343
# Valid Loss = 5.5368
# Epoch:  7
#
# Valid Accuracy:  1%
# Train Loss = 5.7518
# Valid Loss = 5.6044
# Epoch:  8
#
# Valid Accuracy:  1%
# Train Loss = 5.7673
# Valid Loss = 5.7051
# Epoch:  9
#
# Valid Accuracy:  1%
# Train Loss = 5.7722
# Valid Loss = 5.6213
# Epoch:  10
#
# Valid Accuracy:  1%
# Train Loss = 5.7893
# Valid Loss = 5.7797

# %%
test(classes, base_model, test_loader, criterion)
# Out:
# Test Accuracy of ABBOTTS BABBLER:  0% ( 0/ 5)
# Test Accuracy of ABBOTTS BOOBY:  0% ( 0/ 5)
# Test Accuracy of ABYSSINIAN GROUND HORNBILL:  0% ( 0/ 5)
# Test Accuracy of AFRICAN CROWNED CRANE:  0% ( 0/ 5)
# Test Accuracy of AFRICAN EMERALD CUCKOO:  0% ( 0/ 5)
# Test Accuracy of AFRICAN FIREFINCH:  0% ( 0/ 5)
# Test Accuracy of AFRICAN OYSTER CATCHER:  0% ( 0/ 5)
# Test Accuracy of ALBATROSS:  0% ( 0/ 5)
# Test Accuracy of ALBERTS TOWHEE:  0% ( 0/ 5)
# Test Accuracy of ALEXANDRINE PARAKEET:  0% ( 0/ 5)
# Test Accuracy of ALPINE CHOUGH:  0% ( 0/ 5)
# Test Accuracy of ALTAMIRA YELLOWTHROAT:  0% ( 0/ 5)
# Test Accuracy of AMERICAN AVOCET:  0% ( 0/ 5)
# Test Accuracy of AMERICAN BITTERN:  0% ( 0/ 5)
# Test Accuracy of AMERICAN COOT:  0% ( 0/ 5)
# Test Accuracy of AMERICAN GOLDFINCH:  0% ( 0/ 5)
# Test Accuracy of AMERICAN KESTREL:  0% ( 0/ 5)
# Test Accuracy of AMERICAN PIPIT:  0% ( 0/ 5)
# Test Accuracy of AMERICAN REDSTART:  0% ( 0/ 5)
# Test Accuracy of AMETHYST WOODSTAR:  0% ( 0/ 5)
# Test Accuracy of ANDEAN GOOSE:  0% ( 0/ 5)
# Test Accuracy of ANDEAN LAPWING:  0% ( 0/ 5)
# Test Accuracy of ANDEAN SISKIN:  0% ( 0/ 5)
# Test Accuracy of ANHINGA:  0% ( 0/ 5)
# Test Accuracy of ANIANIAU:  0% ( 0/ 5)
# Test Accuracy of ANNAS HUMMINGBIRD:  0% ( 0/ 5)
# Test Accuracy of ANTBIRD:  0% ( 0/ 5)
# Test Accuracy of ANTILLEAN EUPHONIA:  0% ( 0/ 5)
# Test Accuracy of APAPANE:  0% ( 0/ 5)
# Test Accuracy of APOSTLEBIRD:  0% ( 0/ 5)
# Test Accuracy of ARARIPE MANAKIN:  0% ( 0/ 5)
# Test Accuracy of ASHY THRUSHBIRD:  0% ( 0/ 5)
# Test Accuracy of ASIAN CRESTED IBIS:  0% ( 0/ 5)
# Test Accuracy of AZURE JAY:  0% ( 0/ 5)
# Test Accuracy of AZURE TANAGER:  0% ( 0/ 5)
# Test Accuracy of AZURE TIT:  0% ( 0/ 5)
# Test Accuracy of BAIKAL TEAL:  0% ( 0/ 5)
# Test Accuracy of BALD EAGLE:  0% ( 0/ 5)
# Test Accuracy of BALD IBIS:  0% ( 0/ 5)
# Test Accuracy of BALI STARLING:  0% ( 0/ 5)
# Test Accuracy of BALTIMORE ORIOLE:  0% ( 0/ 5)
# Test Accuracy of BANANAQUIT:  0% ( 0/ 5)
# Test Accuracy of BAND TAILED GUAN:  0% ( 0/ 5)
# Test Accuracy of BANDED BROADBILL:  0% ( 0/ 5)
# Test Accuracy of BANDED PITA:  0% ( 0/ 5)
# Test Accuracy of BANDED STILT:  0% ( 0/ 5)
# Test Accuracy of BAR-TAILED GODWIT:  0% ( 0/ 5)
# Test Accuracy of BARN OWL:  0% ( 0/ 5)
# Test Accuracy of BARN SWALLOW:  0% ( 0/ 5)
# Test Accuracy of BARRED PUFFBIRD:  0% ( 0/ 5)
# Test Accuracy of BARROWS GOLDENEYE:  0% ( 0/ 5)
# Test Accuracy of BAY-BREASTED WARBLER:  0% ( 0/ 5)
# Test Accuracy of BEARDED BARBET:  0% ( 0/ 5)
# Test Accuracy of BEARDED BELLBIRD:  0% ( 0/ 5)
# Test Accuracy of BEARDED REEDLING:  0% ( 0/ 5)
# Test Accuracy of BELTED KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of BIRD OF PARADISE:  0% ( 0/ 5)
# Test Accuracy of BLACK & YELLOW  BROADBILL:  0% ( 0/ 5)
# Test Accuracy of BLACK BAZA:  0% ( 0/ 5)
# Test Accuracy of BLACK FRANCOLIN:  0% ( 0/ 5)
# Test Accuracy of BLACK SKIMMER:  0% ( 0/ 5)
# Test Accuracy of BLACK SWAN:  0% ( 0/ 5)
# Test Accuracy of BLACK TAIL CRAKE:  0% ( 0/ 5)
# Test Accuracy of BLACK THROATED BUSHTIT:  0% ( 0/ 5)
# Test Accuracy of BLACK THROATED WARBLER:  0% ( 0/ 5)
# Test Accuracy of BLACK VULTURE:  0% ( 0/ 5)
# Test Accuracy of BLACK-CAPPED CHICKADEE:  0% ( 0/ 5)
# Test Accuracy of BLACK-NECKED GREBE:  0% ( 0/ 5)
# Test Accuracy of BLACK-THROATED SPARROW:  0% ( 0/ 5)
# Test Accuracy of BLACKBURNIAM WARBLER:  0% ( 0/ 5)
# Test Accuracy of BLONDE CRESTED WOODPECKER:  0% ( 0/ 5)
# Test Accuracy of BLUE COAU:  0% ( 0/ 5)
# Test Accuracy of BLUE GROUSE:  0% ( 0/ 5)
# Test Accuracy of BLUE HERON:  0% ( 0/ 5)
# Test Accuracy of BLUE THROATED TOUCANET:  0% ( 0/ 5)
# Test Accuracy of BOBOLINK:  0% ( 0/ 5)
# Test Accuracy of BORNEAN BRISTLEHEAD:  0% ( 0/ 5)
# Test Accuracy of BORNEAN LEAFBIRD:  0% ( 0/ 5)
# Test Accuracy of BORNEAN PHEASANT:  0% ( 0/ 5)
# Test Accuracy of BRANDT CORMARANT:  0% ( 0/ 5)
# Test Accuracy of BROWN CREPPER:  0% ( 0/ 5)
# Test Accuracy of BROWN NOODY:  0% ( 0/ 5)
# Test Accuracy of BROWN THRASHER:  0% ( 0/ 5)
# Test Accuracy of BULWERS PHEASANT:  0% ( 0/ 5)
# Test Accuracy of BUSH TURKEY:  0% ( 0/ 5)
# Test Accuracy of CACTUS WREN:  0% ( 0/ 5)
# Test Accuracy of CALIFORNIA CONDOR:  0% ( 0/ 5)
# Test Accuracy of CALIFORNIA GULL:  0% ( 0/ 5)
# Test Accuracy of CALIFORNIA QUAIL:  0% ( 0/ 5)
# Test Accuracy of CANARY:  0% ( 0/ 5)
# Test Accuracy of CAPE GLOSSY STARLING:  0% ( 0/ 5)
# Test Accuracy of CAPE MAY WARBLER:  0% ( 0/ 5)
# Test Accuracy of CAPPED HERON:  0% ( 0/ 5)
# Test Accuracy of CAPUCHINBIRD:  0% ( 0/ 5)
# Test Accuracy of CARMINE BEE-EATER:  0% ( 0/ 5)
# Test Accuracy of CASPIAN TERN:  0% ( 0/ 5)
# Test Accuracy of CASSOWARY:  0% ( 0/ 5)
# Test Accuracy of CEDAR WAXWING:  0% ( 0/ 5)
# Test Accuracy of CERULEAN WARBLER:  0% ( 0/ 5)
# Test Accuracy of CHARA DE COLLAR:  0% ( 0/ 5)
# Test Accuracy of CHESTNET BELLIED EUPHONIA:  0% ( 0/ 5)
# Test Accuracy of CHIPPING SPARROW:  0% ( 0/ 5)
# Test Accuracy of CHUKAR PARTRIDGE: 60% ( 3/ 5)
# Test Accuracy of CINNAMON TEAL:  0% ( 0/ 5)
# Test Accuracy of CLARKS NUTCRACKER:  0% ( 0/ 5)
# Test Accuracy of COCK OF THE  ROCK:  0% ( 0/ 5)
# Test Accuracy of COCKATOO:  0% ( 0/ 5)
# Test Accuracy of COLLARED ARACARI:  0% ( 0/ 5)
# Test Accuracy of COMMON FIRECREST:  0% ( 0/ 5)
# Test Accuracy of COMMON GRACKLE:  0% ( 0/ 5)
# Test Accuracy of COMMON HOUSE MARTIN:  0% ( 0/ 5)
# Test Accuracy of COMMON LOON:  0% ( 0/ 5)
# Test Accuracy of COMMON POORWILL:  0% ( 0/ 5)
# Test Accuracy of COMMON STARLING:  0% ( 0/ 5)
# Test Accuracy of CRESTED AUKLET:  0% ( 0/ 5)
# Test Accuracy of CRESTED CARACARA:  0% ( 0/ 5)
# Test Accuracy of CRESTED NUTHATCH:  0% ( 0/ 5)
# Test Accuracy of CRIMSON SUNBIRD:  0% ( 0/ 5)
# Test Accuracy of  CROW:  0% ( 0/ 5)
# Test Accuracy of CROWNED PIGEON:  0% ( 0/ 5)
# Test Accuracy of CUBAN TODY:  0% ( 0/ 5)
# Test Accuracy of CUBAN TROGON:  0% ( 0/ 5)
# Test Accuracy of CURL CRESTED ARACURI:  0% ( 0/ 5)
# Test Accuracy of D-ARNAUDS BARBET:  0% ( 0/ 5)
# Test Accuracy of DARK EYED JUNCO: 20% ( 1/ 5)
# Test Accuracy of DOUBLE BARRED FINCH:  0% ( 0/ 5)
# Test Accuracy of DOUBLE BRESTED CORMARANT:  0% ( 0/ 5)
# Test Accuracy of DOWNY WOODPECKER:  0% ( 0/ 5)
# Test Accuracy of EASTERN BLUEBIRD:  0% ( 0/ 5)
# Test Accuracy of EASTERN MEADOWLARK:  0% ( 0/ 5)
# Test Accuracy of EASTERN ROSELLA:  0% ( 0/ 5)
# Test Accuracy of EASTERN TOWEE:  0% ( 0/ 5)
# Test Accuracy of ELEGANT TROGON:  0% ( 0/ 5)
# Test Accuracy of ELLIOTS  PHEASANT:  0% ( 0/ 5)
# Test Accuracy of EMPEROR PENGUIN: 100% ( 5/ 5)
# Test Accuracy of   EMU:  0% ( 0/ 5)
# Test Accuracy of ENGGANO MYNA:  0% ( 0/ 5)
# Test Accuracy of EURASIAN GOLDEN ORIOLE:  0% ( 0/ 5)
# Test Accuracy of EURASIAN MAGPIE:  0% ( 0/ 5)
# Test Accuracy of EVENING GROSBEAK:  0% ( 0/ 5)
# Test Accuracy of FAIRY BLUEBIRD:  0% ( 0/ 5)
# Test Accuracy of FIRE TAILLED MYZORNIS:  0% ( 0/ 5)
# Test Accuracy of FLAME TANAGER:  0% ( 0/ 5)
# Test Accuracy of FLAMINGO:  0% ( 0/ 5)
# Test Accuracy of FRIGATE:  0% ( 0/ 5)
# Test Accuracy of GAMBELS QUAIL:  0% ( 0/ 5)
# Test Accuracy of GANG GANG COCKATOO:  0% ( 0/ 5)
# Test Accuracy of GILA WOODPECKER:  0% ( 0/ 5)
# Test Accuracy of GILDED FLICKER:  0% ( 0/ 5)
# Test Accuracy of GLOSSY IBIS:  0% ( 0/ 5)
# Test Accuracy of GO AWAY BIRD:  0% ( 0/ 5)
# Test Accuracy of GOLD WING WARBLER:  0% ( 0/ 5)
# Test Accuracy of GOLDEN CHEEKED WARBLER:  0% ( 0/ 5)
# Test Accuracy of GOLDEN CHLOROPHONIA:  0% ( 0/ 5)
# Test Accuracy of GOLDEN EAGLE:  0% ( 0/ 5)
# Test Accuracy of GOLDEN PHEASANT:  0% ( 0/ 5)
# Test Accuracy of GOLDEN PIPIT:  0% ( 0/ 5)
# Test Accuracy of GOULDIAN FINCH:  0% ( 0/ 5)
# Test Accuracy of GRAY CATBIRD:  0% ( 0/ 5)
# Test Accuracy of GRAY KINGBIRD:  0% ( 0/ 5)
# Test Accuracy of GRAY PARTRIDGE:  0% ( 0/ 5)
# Test Accuracy of GREAT GRAY OWL:  0% ( 0/ 5)
# Test Accuracy of GREAT KISKADEE:  0% ( 0/ 5)
# Test Accuracy of GREAT POTOO:  0% ( 0/ 5)
# Test Accuracy of GREATOR SAGE GROUSE:  0% ( 0/ 5)
# Test Accuracy of GREEN BROADBILL:  0% ( 0/ 5)
# Test Accuracy of GREEN JAY:  0% ( 0/ 5)
# Test Accuracy of GREEN MAGPIE:  0% ( 0/ 5)
# Test Accuracy of GREY PLOVER:  0% ( 0/ 5)
# Test Accuracy of GROVED BILLED ANI:  0% ( 0/ 5)
# Test Accuracy of GUINEA TURACO:  0% ( 0/ 5)
# Test Accuracy of GUINEAFOWL:  0% ( 0/ 5)
# Test Accuracy of GYRFALCON:  0% ( 0/ 5)
# Test Accuracy of HARLEQUIN DUCK:  0% ( 0/ 5)
# Test Accuracy of HARPY EAGLE:  0% ( 0/ 5)
# Test Accuracy of HAWAIIAN GOOSE:  0% ( 0/ 5)
# Test Accuracy of HELMET VANGA:  0% ( 0/ 5)
# Test Accuracy of HIMALAYAN MONAL:  0% ( 0/ 5)
# Test Accuracy of HOATZIN:  0% ( 0/ 5)
# Test Accuracy of HOODED MERGANSER:  0% ( 0/ 5)
# Test Accuracy of HOOPOES:  0% ( 0/ 5)
# Test Accuracy of HORNBILL:  0% ( 0/ 5)
# Test Accuracy of HORNED GUAN:  0% ( 0/ 5)
# Test Accuracy of HORNED LARK:  0% ( 0/ 5)
# Test Accuracy of HORNED SUNGEM:  0% ( 0/ 5)
# Test Accuracy of HOUSE FINCH: 100% ( 5/ 5)
# Test Accuracy of HOUSE SPARROW:  0% ( 0/ 5)
# Test Accuracy of HYACINTH MACAW:  0% ( 0/ 5)
# Test Accuracy of IMPERIAL SHAQ:  0% ( 0/ 5)
# Test Accuracy of INCA TERN:  0% ( 0/ 5)
# Test Accuracy of INDIAN BUSTARD:  0% ( 0/ 5)
# Test Accuracy of INDIAN PITTA:  0% ( 0/ 5)
# Test Accuracy of INDIAN ROLLER:  0% ( 0/ 5)
# Test Accuracy of INDIGO BUNTING:  0% ( 0/ 5)
# Test Accuracy of   IWI:  0% ( 0/ 5)
# Test Accuracy of JABIRU:  0% ( 0/ 5)
# Test Accuracy of JAVA SPARROW:  0% ( 0/ 5)
# Test Accuracy of  KAGU:  0% ( 0/ 5)
# Test Accuracy of KAKAPO:  0% ( 0/ 5)
# Test Accuracy of KILLDEAR:  0% ( 0/ 5)
# Test Accuracy of KING VULTURE:  0% ( 0/ 5)
# Test Accuracy of  KIWI:  0% ( 0/ 5)
# Test Accuracy of KOOKABURRA:  0% ( 0/ 5)
# Test Accuracy of LARK BUNTING:  0% ( 0/ 5)
# Test Accuracy of LAZULI BUNTING:  0% ( 0/ 5)
# Test Accuracy of LILAC ROLLER:  0% ( 0/ 5)
# Test Accuracy of LONG-EARED OWL:  0% ( 0/ 5)
# Test Accuracy of MAGPIE GOOSE:  0% ( 0/ 5)
# Test Accuracy of MALABAR HORNBILL:  0% ( 0/ 5)
# Test Accuracy of MALACHITE KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of MALAGASY WHITE EYE:  0% ( 0/ 5)
# Test Accuracy of MALEO:  0% ( 0/ 5)
# Test Accuracy of MALLARD DUCK:  0% ( 0/ 5)
# Test Accuracy of MANDRIN DUCK:  0% ( 0/ 5)
# Test Accuracy of MANGROVE CUCKOO:  0% ( 0/ 5)
# Test Accuracy of MARABOU STORK:  0% ( 0/ 5)
# Test Accuracy of MASKED BOOBY:  0% ( 0/ 5)
# Test Accuracy of MASKED LAPWING:  0% ( 0/ 5)
# Test Accuracy of MIKADO  PHEASANT:  0% ( 0/ 5)
# Test Accuracy of MOURNING DOVE:  0% ( 0/ 5)
# Test Accuracy of  MYNA:  0% ( 0/ 5)
# Test Accuracy of NICOBAR PIGEON:  0% ( 0/ 5)
# Test Accuracy of NOISY FRIARBIRD:  0% ( 0/ 5)
# Test Accuracy of NORTHERN CARDINAL:  0% ( 0/ 5)
# Test Accuracy of NORTHERN FLICKER:  0% ( 0/ 5)
# Test Accuracy of NORTHERN FULMAR:  0% ( 0/ 5)
# Test Accuracy of NORTHERN GANNET:  0% ( 0/ 5)
# Test Accuracy of NORTHERN GOSHAWK:  0% ( 0/ 5)
# Test Accuracy of NORTHERN JACANA:  0% ( 0/ 5)
# Test Accuracy of NORTHERN MOCKINGBIRD:  0% ( 0/ 5)
# Test Accuracy of NORTHERN PARULA:  0% ( 0/ 5)
# Test Accuracy of NORTHERN RED BISHOP:  0% ( 0/ 5)
# Test Accuracy of NORTHERN SHOVELER:  0% ( 0/ 5)
# Test Accuracy of OCELLATED TURKEY:  0% ( 0/ 5)
# Test Accuracy of OKINAWA RAIL:  0% ( 0/ 5)
# Test Accuracy of ORANGE BRESTED BUNTING:  0% ( 0/ 5)
# Test Accuracy of ORIENTAL BAY OWL:  0% ( 0/ 5)
# Test Accuracy of OSPREY:  0% ( 0/ 5)
# Test Accuracy of OSTRICH:  0% ( 0/ 5)
# Test Accuracy of OVENBIRD:  0% ( 0/ 5)
# Test Accuracy of OYSTER CATCHER: 60% ( 3/ 5)
# Test Accuracy of PAINTED BUNTING:  0% ( 0/ 5)
# Test Accuracy of PALILA:  0% ( 0/ 5)
# Test Accuracy of PARADISE TANAGER:  0% ( 0/ 5)
# Test Accuracy of PARAKETT  AKULET:  0% ( 0/ 5)
# Test Accuracy of PARUS MAJOR:  0% ( 0/ 5)
# Test Accuracy of PATAGONIAN SIERRA FINCH:  0% ( 0/ 5)
# Test Accuracy of PEACOCK: 60% ( 3/ 5)
# Test Accuracy of PELICAN:  0% ( 0/ 5)
# Test Accuracy of PEREGRINE FALCON:  0% ( 0/ 5)
# Test Accuracy of PHILIPPINE EAGLE:  0% ( 0/ 5)
# Test Accuracy of PINK ROBIN:  0% ( 0/ 5)
# Test Accuracy of POMARINE JAEGER:  0% ( 0/ 5)
# Test Accuracy of PUFFIN:  0% ( 0/ 5)
# Test Accuracy of PURPLE FINCH:  0% ( 0/ 5)
# Test Accuracy of PURPLE GALLINULE:  0% ( 0/ 5)
# Test Accuracy of PURPLE MARTIN:  0% ( 0/ 5)
# Test Accuracy of PURPLE SWAMPHEN:  0% ( 0/ 5)
# Test Accuracy of PYGMY KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of QUETZAL:  0% ( 0/ 5)
# Test Accuracy of RAINBOW LORIKEET:  0% ( 0/ 5)
# Test Accuracy of RAZORBILL:  0% ( 0/ 5)
# Test Accuracy of RED BEARDED BEE EATER: 40% ( 2/ 5)
# Test Accuracy of RED BELLIED PITTA:  0% ( 0/ 5)
# Test Accuracy of RED BROWED FINCH:  0% ( 0/ 5)
# Test Accuracy of RED FACED CORMORANT:  0% ( 0/ 5)
# Test Accuracy of RED FACED WARBLER:  0% ( 0/ 5)
# Test Accuracy of RED FODY:  0% ( 0/ 5)
# Test Accuracy of RED HEADED DUCK:  0% ( 0/ 5)
# Test Accuracy of RED HEADED WOODPECKER:  0% ( 0/ 5)
# Test Accuracy of RED HONEY CREEPER:  0% ( 0/ 5)
# Test Accuracy of RED NAPED TROGON:  0% ( 0/ 5)
# Test Accuracy of RED TAILED HAWK:  0% ( 0/ 5)
# Test Accuracy of RED TAILED THRUSH:  0% ( 0/ 5)
# Test Accuracy of RED WINGED BLACKBIRD:  0% ( 0/ 5)
# Test Accuracy of RED WISKERED BULBUL:  0% ( 0/ 5)
# Test Accuracy of REGENT BOWERBIRD:  0% ( 0/ 5)
# Test Accuracy of RING-NECKED PHEASANT:  0% ( 0/ 5)
# Test Accuracy of ROADRUNNER:  0% ( 0/ 5)
# Test Accuracy of ROBIN:  0% ( 0/ 5)
# Test Accuracy of ROCK DOVE:  0% ( 0/ 5)
# Test Accuracy of ROSY FACED LOVEBIRD:  0% ( 0/ 5)
# Test Accuracy of ROUGH LEG BUZZARD:  0% ( 0/ 5)
# Test Accuracy of ROYAL FLYCATCHER:  0% ( 0/ 5)
# Test Accuracy of RUBY THROATED HUMMINGBIRD:  0% ( 0/ 5)
# Test Accuracy of RUDY KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of RUFOUS KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of RUFUOS MOTMOT:  0% ( 0/ 5)
# Test Accuracy of SAMATRAN THRUSH:  0% ( 0/ 5)
# Test Accuracy of SAND MARTIN:  0% ( 0/ 5)
# Test Accuracy of SANDHILL CRANE:  0% ( 0/ 5)
# Test Accuracy of SATYR TRAGOPAN:  0% ( 0/ 5)
# Test Accuracy of SCARLET CROWNED FRUIT DOVE:  0% ( 0/ 5)
# Test Accuracy of SCARLET IBIS:  0% ( 0/ 5)
# Test Accuracy of SCARLET MACAW:  0% ( 0/ 5)
# Test Accuracy of SCARLET TANAGER:  0% ( 0/ 5)
# Test Accuracy of SHOEBILL:  0% ( 0/ 5)
# Test Accuracy of SHORT BILLED DOWITCHER:  0% ( 0/ 5)
# Test Accuracy of SMITHS LONGSPUR:  0% ( 0/ 5)
# Test Accuracy of SNOWY EGRET:  0% ( 0/ 5)
# Test Accuracy of SNOWY OWL:  0% ( 0/ 5)
# Test Accuracy of  SORA:  0% ( 0/ 5)
# Test Accuracy of SPANGLED COTINGA:  0% ( 0/ 5)
# Test Accuracy of SPLENDID WREN:  0% ( 0/ 5)
# Test Accuracy of SPOON BILED SANDPIPER:  0% ( 0/ 5)
# Test Accuracy of SPOONBILL:  0% ( 0/ 5)
# Test Accuracy of SPOTTED CATBIRD:  0% ( 0/ 5)
# Test Accuracy of SRI LANKA BLUE MAGPIE:  0% ( 0/ 5)
# Test Accuracy of STEAMER DUCK:  0% ( 0/ 5)
# Test Accuracy of STORK BILLED KINGFISHER:  0% ( 0/ 5)
# Test Accuracy of STRAWBERRY FINCH:  0% ( 0/ 5)
# Test Accuracy of STRIPED OWL:  0% ( 0/ 5)
# Test Accuracy of STRIPPED MANAKIN:  0% ( 0/ 5)
# Test Accuracy of STRIPPED SWALLOW:  0% ( 0/ 5)
# Test Accuracy of SUPERB STARLING:  0% ( 0/ 5)
# Test Accuracy of SWINHOES PHEASANT:  0% ( 0/ 5)
# Test Accuracy of TAIWAN MAGPIE:  0% ( 0/ 5)
# Test Accuracy of TAKAHE:  0% ( 0/ 5)
# Test Accuracy of TASMANIAN HEN:  0% ( 0/ 5)
# Test Accuracy of TEAL DUCK:  0% ( 0/ 5)
# Test Accuracy of TIT MOUSE:  0% ( 0/ 5)
# Test Accuracy of TOUCHAN:  0% ( 0/ 5)
# Test Accuracy of TOWNSENDS WARBLER:  0% ( 0/ 5)
# Test Accuracy of TREE SWALLOW:  0% ( 0/ 5)
# Test Accuracy of TROPICAL KINGBIRD:  0% ( 0/ 5)
# Test Accuracy of TRUMPTER SWAN: 20% ( 1/ 5)
# Test Accuracy of TURKEY VULTURE:  0% ( 0/ 5)
# Test Accuracy of TURQUOISE MOTMOT: 20% ( 1/ 5)
# Test Accuracy of UMBRELLA BIRD:  0% ( 0/ 5)
# Test Accuracy of VARIED THRUSH:  0% ( 0/ 5)
# Test Accuracy of VENEZUELIAN TROUPIAL:  0% ( 0/ 5)
# Test Accuracy of VERMILION FLYCATHER:  0% ( 0/ 5)
# Test Accuracy of VICTORIA CROWNED PIGEON: 40% ( 2/ 5)
# Test Accuracy of VIOLET GREEN SWALLOW:  0% ( 0/ 5)
# Test Accuracy of VULTURINE GUINEAFOWL:  0% ( 0/ 5)
# Test Accuracy of WALL CREAPER:  0% ( 0/ 5)
# Test Accuracy of WATTLED CURASSOW:  0% ( 0/ 5)
# Test Accuracy of WATTLED LAPWING:  0% ( 0/ 5)
# Test Accuracy of WHIMBREL:  0% ( 0/ 5)
# Test Accuracy of WHITE BROWED CRAKE:  0% ( 0/ 5)
# Test Accuracy of WHITE CHEEKED TURACO:  0% ( 0/ 5)
# Test Accuracy of WHITE NECKED RAVEN:  0% ( 0/ 5)
# Test Accuracy of WHITE TAILED TROPIC:  0% ( 0/ 5)
# Test Accuracy of WHITE THROATED BEE EATER:  0% ( 0/ 5)
# Test Accuracy of WILD TURKEY:  0% ( 0/ 5)
# Test Accuracy of WILSONS BIRD OF PARADISE:  0% ( 0/ 5)
# Test Accuracy of WOOD DUCK:  0% ( 0/ 5)
# Test Accuracy of YELLOW BELLIED FLOWERPECKER:  0% ( 0/ 5)
# Test Accuracy of YELLOW CACIQUE:  0% ( 0/ 5)
# Test Accuracy of YELLOW HEADED BLACKBIRD:  0% ( 0/ 5)
# Test Loss: 5.779457
#
#
# Test Accuracy (Overall):  1% (26/1750)

# %% [markdown]
# > Benchmark Model -- ResNet 18

# %% [markdown]
# ResNet is a network architecture build in 2016, with maximum 152 CNN layers. In ResNet, the output from the previous layer, called residual, is added to the output of the current layer. This changing decreases the error rate for deeper networks, but adds complexity of the model. Besides, ResNet gained a 28% improvement on the famous image recognition benchmark dataset named COCO (Lin et al. 2014).

# %% [markdown]
# The number of layers varies from 18 to 152. The ResNet 18 network contains 18 CNN layers.

# %%
from torchvision import models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model = models.resnet18(pretrained=True)

# turn training false for all layers, other than fc layer
for param in base_model.parameters():
    param.requires_grad = False
    
num_ftrs = base_model.fc.in_features
base_model.fc = nn.Linear(num_ftrs, len(classes))
base_model = base_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(base_model.parameters(), lr = 0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# - The neural network architecture of ResNet 18 model is shown below.

# %%
summary(base_model, (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 350]         179,550
# ================================================================
# Total params: 11,356,062
# Trainable params: 179,550
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 43.32
# Estimated Total Size (MB): 106.68
# ----------------------------------------------------------------

# %%
train(10, base_model, train_loader, optimizer, criterion, valid_loader)
# Out:
# Epoch:  1
#
# Valid Accuracy: 88%
# Train Loss = 1.7502
# Valid Loss = 0.4494
# Epoch:  2
#
# Valid Accuracy: 89%
# Train Loss = 0.6778
# Valid Loss = 0.351
# Epoch:  3
#
# Valid Accuracy: 91%
# Train Loss = 0.5307
# Valid Loss = 0.2878
# Epoch:  4
#
# Valid Accuracy: 90%
# Train Loss = 0.4466
# Valid Loss = 0.2856
# Epoch:  5
#
# Valid Accuracy: 92%
# Train Loss = 0.3987
# Valid Loss = 0.2555
# Epoch:  6
#
# Valid Accuracy: 92%
# Train Loss = 0.3601
# Valid Loss = 0.2523
# Epoch:  7
#
# Valid Accuracy: 92%
# Train Loss = 0.3277
# Valid Loss = 0.2511
# Epoch:  8
#
# Valid Accuracy: 92%
# Train Loss = 0.3093
# Valid Loss = 0.2701
# Epoch:  9
#
# Valid Accuracy: 92%
# Train Loss = 0.2845
# Valid Loss = 0.2742
# Epoch:  10
#
# Valid Accuracy: 92%
# Train Loss = 0.2702
# Valid Loss = 0.2606

# %%
test(classes, base_model, test_loader, criterion)
# Out:
# Test Accuracy of ABBOTTS BABBLER: 20% ( 1/ 5)
# Test Accuracy of ABBOTTS BOOBY: 40% ( 2/ 5)
# Test Accuracy of ABYSSINIAN GROUND HORNBILL: 100% ( 5/ 5)
# Test Accuracy of AFRICAN CROWNED CRANE: 100% ( 5/ 5)
# Test Accuracy of AFRICAN EMERALD CUCKOO: 60% ( 3/ 5)
# Test Accuracy of AFRICAN FIREFINCH: 80% ( 4/ 5)
# Test Accuracy of AFRICAN OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of ALBATROSS: 100% ( 5/ 5)
# Test Accuracy of ALBERTS TOWHEE: 100% ( 5/ 5)
# Test Accuracy of ALEXANDRINE PARAKEET: 80% ( 4/ 5)
# Test Accuracy of ALPINE CHOUGH: 100% ( 5/ 5)
# Test Accuracy of ALTAMIRA YELLOWTHROAT: 60% ( 3/ 5)
# Test Accuracy of AMERICAN AVOCET: 100% ( 5/ 5)
# Test Accuracy of AMERICAN BITTERN: 100% ( 5/ 5)
# Test Accuracy of AMERICAN COOT: 100% ( 5/ 5)
# Test Accuracy of AMERICAN GOLDFINCH: 100% ( 5/ 5)
# Test Accuracy of AMERICAN KESTREL: 100% ( 5/ 5)
# Test Accuracy of AMERICAN PIPIT: 80% ( 4/ 5)
# Test Accuracy of AMERICAN REDSTART: 60% ( 3/ 5)
# Test Accuracy of AMETHYST WOODSTAR: 80% ( 4/ 5)
# Test Accuracy of ANDEAN GOOSE: 100% ( 5/ 5)
# Test Accuracy of ANDEAN LAPWING: 100% ( 5/ 5)
# Test Accuracy of ANDEAN SISKIN: 80% ( 4/ 5)
# Test Accuracy of ANHINGA: 100% ( 5/ 5)
# Test Accuracy of ANIANIAU: 80% ( 4/ 5)
# Test Accuracy of ANNAS HUMMINGBIRD: 100% ( 5/ 5)
# Test Accuracy of ANTBIRD: 100% ( 5/ 5)
# Test Accuracy of ANTILLEAN EUPHONIA: 80% ( 4/ 5)
# Test Accuracy of APAPANE: 80% ( 4/ 5)
# Test Accuracy of APOSTLEBIRD: 100% ( 5/ 5)
# Test Accuracy of ARARIPE MANAKIN: 100% ( 5/ 5)
# Test Accuracy of ASHY THRUSHBIRD: 80% ( 4/ 5)
# Test Accuracy of ASIAN CRESTED IBIS: 100% ( 5/ 5)
# Test Accuracy of AZURE JAY: 60% ( 3/ 5)
# Test Accuracy of AZURE TANAGER: 80% ( 4/ 5)
# Test Accuracy of AZURE TIT: 80% ( 4/ 5)
# Test Accuracy of BAIKAL TEAL: 100% ( 5/ 5)
# Test Accuracy of BALD EAGLE: 100% ( 5/ 5)
# Test Accuracy of BALD IBIS: 80% ( 4/ 5)
# Test Accuracy of BALI STARLING: 100% ( 5/ 5)
# Test Accuracy of BALTIMORE ORIOLE: 60% ( 3/ 5)
# Test Accuracy of BANANAQUIT: 100% ( 5/ 5)
# Test Accuracy of BAND TAILED GUAN: 80% ( 4/ 5)
# Test Accuracy of BANDED BROADBILL: 100% ( 5/ 5)
# Test Accuracy of BANDED PITA: 100% ( 5/ 5)
# Test Accuracy of BANDED STILT: 100% ( 5/ 5)
# Test Accuracy of BAR-TAILED GODWIT: 100% ( 5/ 5)
# Test Accuracy of BARN OWL: 80% ( 4/ 5)
# Test Accuracy of BARN SWALLOW: 100% ( 5/ 5)
# Test Accuracy of BARRED PUFFBIRD: 100% ( 5/ 5)
# Test Accuracy of BARROWS GOLDENEYE: 60% ( 3/ 5)
# Test Accuracy of BAY-BREASTED WARBLER: 100% ( 5/ 5)
# Test Accuracy of BEARDED BARBET: 100% ( 5/ 5)
# Test Accuracy of BEARDED BELLBIRD: 100% ( 5/ 5)
# Test Accuracy of BEARDED REEDLING: 100% ( 5/ 5)
# Test Accuracy of BELTED KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of BLACK & YELLOW  BROADBILL: 100% ( 5/ 5)
# Test Accuracy of BLACK BAZA: 60% ( 3/ 5)
# Test Accuracy of BLACK FRANCOLIN: 80% ( 4/ 5)
# Test Accuracy of BLACK SKIMMER: 60% ( 3/ 5)
# Test Accuracy of BLACK SWAN: 100% ( 5/ 5)
# Test Accuracy of BLACK TAIL CRAKE: 80% ( 4/ 5)
# Test Accuracy of BLACK THROATED BUSHTIT: 100% ( 5/ 5)
# Test Accuracy of BLACK THROATED WARBLER: 100% ( 5/ 5)
# Test Accuracy of BLACK VULTURE: 100% ( 5/ 5)
# Test Accuracy of BLACK-CAPPED CHICKADEE: 80% ( 4/ 5)
# Test Accuracy of BLACK-NECKED GREBE: 100% ( 5/ 5)
# Test Accuracy of BLACK-THROATED SPARROW: 100% ( 5/ 5)
# Test Accuracy of BLACKBURNIAM WARBLER: 80% ( 4/ 5)
# Test Accuracy of BLONDE CRESTED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of BLUE COAU: 80% ( 4/ 5)
# Test Accuracy of BLUE GROUSE: 100% ( 5/ 5)
# Test Accuracy of BLUE HERON: 100% ( 5/ 5)
# Test Accuracy of BLUE THROATED TOUCANET: 100% ( 5/ 5)
# Test Accuracy of BOBOLINK: 80% ( 4/ 5)
# Test Accuracy of BORNEAN BRISTLEHEAD: 100% ( 5/ 5)
# Test Accuracy of BORNEAN LEAFBIRD: 100% ( 5/ 5)
# Test Accuracy of BORNEAN PHEASANT: 100% ( 5/ 5)
# Test Accuracy of BRANDT CORMARANT: 80% ( 4/ 5)
# Test Accuracy of BROWN CREPPER: 100% ( 5/ 5)
# Test Accuracy of BROWN NOODY: 100% ( 5/ 5)
# Test Accuracy of BROWN THRASHER: 60% ( 3/ 5)
# Test Accuracy of BULWERS PHEASANT: 100% ( 5/ 5)
# Test Accuracy of BUSH TURKEY: 100% ( 5/ 5)
# Test Accuracy of CACTUS WREN: 100% ( 5/ 5)
# Test Accuracy of CALIFORNIA CONDOR: 100% ( 5/ 5)
# Test Accuracy of CALIFORNIA GULL: 80% ( 4/ 5)
# Test Accuracy of CALIFORNIA QUAIL: 100% ( 5/ 5)
# Test Accuracy of CANARY: 100% ( 5/ 5)
# Test Accuracy of CAPE GLOSSY STARLING: 100% ( 5/ 5)
# Test Accuracy of CAPE MAY WARBLER: 80% ( 4/ 5)
# Test Accuracy of CAPPED HERON: 100% ( 5/ 5)
# Test Accuracy of CAPUCHINBIRD: 100% ( 5/ 5)
# Test Accuracy of CARMINE BEE-EATER: 80% ( 4/ 5)
# Test Accuracy of CASPIAN TERN: 100% ( 5/ 5)
# Test Accuracy of CASSOWARY: 100% ( 5/ 5)
# Test Accuracy of CEDAR WAXWING: 100% ( 5/ 5)
# Test Accuracy of CERULEAN WARBLER: 100% ( 5/ 5)
# Test Accuracy of CHARA DE COLLAR: 100% ( 5/ 5)
# Test Accuracy of CHESTNET BELLIED EUPHONIA: 100% ( 5/ 5)
# Test Accuracy of CHIPPING SPARROW: 80% ( 4/ 5)
# Test Accuracy of CHUKAR PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of CINNAMON TEAL: 100% ( 5/ 5)
# Test Accuracy of CLARKS NUTCRACKER: 100% ( 5/ 5)
# Test Accuracy of COCK OF THE  ROCK: 100% ( 5/ 5)
# Test Accuracy of COCKATOO: 100% ( 5/ 5)
# Test Accuracy of COLLARED ARACARI: 100% ( 5/ 5)
# Test Accuracy of COMMON FIRECREST: 100% ( 5/ 5)
# Test Accuracy of COMMON GRACKLE: 100% ( 5/ 5)
# Test Accuracy of COMMON HOUSE MARTIN: 100% ( 5/ 5)
# Test Accuracy of COMMON LOON: 100% ( 5/ 5)
# Test Accuracy of COMMON POORWILL: 100% ( 5/ 5)
# Test Accuracy of COMMON STARLING: 100% ( 5/ 5)
# Test Accuracy of CRESTED AUKLET: 100% ( 5/ 5)
# Test Accuracy of CRESTED CARACARA: 100% ( 5/ 5)
# Test Accuracy of CRESTED NUTHATCH: 80% ( 4/ 5)
# Test Accuracy of CRIMSON SUNBIRD: 100% ( 5/ 5)
# Test Accuracy of  CROW: 100% ( 5/ 5)
# Test Accuracy of CROWNED PIGEON: 100% ( 5/ 5)
# Test Accuracy of CUBAN TODY: 100% ( 5/ 5)
# Test Accuracy of CUBAN TROGON: 100% ( 5/ 5)
# Test Accuracy of CURL CRESTED ARACURI: 100% ( 5/ 5)
# Test Accuracy of D-ARNAUDS BARBET: 100% ( 5/ 5)
# Test Accuracy of DARK EYED JUNCO: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BARRED FINCH: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BRESTED CORMARANT: 40% ( 2/ 5)
# Test Accuracy of DOWNY WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of EASTERN BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of EASTERN MEADOWLARK: 100% ( 5/ 5)
# Test Accuracy of EASTERN ROSELLA: 100% ( 5/ 5)
# Test Accuracy of EASTERN TOWEE: 80% ( 4/ 5)
# Test Accuracy of ELEGANT TROGON: 100% ( 5/ 5)
# Test Accuracy of ELLIOTS  PHEASANT: 100% ( 5/ 5)
# Test Accuracy of EMPEROR PENGUIN: 100% ( 5/ 5)
# Test Accuracy of   EMU: 100% ( 5/ 5)
# Test Accuracy of ENGGANO MYNA: 100% ( 5/ 5)
# Test Accuracy of EURASIAN GOLDEN ORIOLE: 100% ( 5/ 5)
# Test Accuracy of EURASIAN MAGPIE: 80% ( 4/ 5)
# Test Accuracy of EVENING GROSBEAK: 80% ( 4/ 5)
# Test Accuracy of FAIRY BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of FIRE TAILLED MYZORNIS: 100% ( 5/ 5)
# Test Accuracy of FLAME TANAGER: 80% ( 4/ 5)
# Test Accuracy of FLAMINGO: 100% ( 5/ 5)
# Test Accuracy of FRIGATE: 100% ( 5/ 5)
# Test Accuracy of GAMBELS QUAIL: 100% ( 5/ 5)
# Test Accuracy of GANG GANG COCKATOO: 100% ( 5/ 5)
# Test Accuracy of GILA WOODPECKER: 80% ( 4/ 5)
# Test Accuracy of GILDED FLICKER: 60% ( 3/ 5)
# Test Accuracy of GLOSSY IBIS: 100% ( 5/ 5)
# Test Accuracy of GO AWAY BIRD: 100% ( 5/ 5)
# Test Accuracy of GOLD WING WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHEEKED WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHLOROPHONIA: 100% ( 5/ 5)
# Test Accuracy of GOLDEN EAGLE: 100% ( 5/ 5)
# Test Accuracy of GOLDEN PHEASANT: 100% ( 5/ 5)
# Test Accuracy of GOLDEN PIPIT: 100% ( 5/ 5)
# Test Accuracy of GOULDIAN FINCH: 100% ( 5/ 5)
# Test Accuracy of GRAY CATBIRD: 100% ( 5/ 5)
# Test Accuracy of GRAY KINGBIRD: 100% ( 5/ 5)
# Test Accuracy of GRAY PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of GREAT GRAY OWL: 100% ( 5/ 5)
# Test Accuracy of GREAT KISKADEE: 100% ( 5/ 5)
# Test Accuracy of GREAT POTOO: 100% ( 5/ 5)
# Test Accuracy of GREATOR SAGE GROUSE: 100% ( 5/ 5)
# Test Accuracy of GREEN BROADBILL: 100% ( 5/ 5)
# Test Accuracy of GREEN JAY: 100% ( 5/ 5)
# Test Accuracy of GREEN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of GREY PLOVER: 100% ( 5/ 5)
# Test Accuracy of GROVED BILLED ANI: 80% ( 4/ 5)
# Test Accuracy of GUINEA TURACO: 100% ( 5/ 5)
# Test Accuracy of GUINEAFOWL: 100% ( 5/ 5)
# Test Accuracy of GYRFALCON: 80% ( 4/ 5)
# Test Accuracy of HARLEQUIN DUCK: 100% ( 5/ 5)
# Test Accuracy of HARPY EAGLE: 100% ( 5/ 5)
# Test Accuracy of HAWAIIAN GOOSE: 100% ( 5/ 5)
# Test Accuracy of HELMET VANGA: 100% ( 5/ 5)
# Test Accuracy of HIMALAYAN MONAL: 100% ( 5/ 5)
# Test Accuracy of HOATZIN: 100% ( 5/ 5)
# Test Accuracy of HOODED MERGANSER: 100% ( 5/ 5)
# Test Accuracy of HOOPOES: 100% ( 5/ 5)
# Test Accuracy of HORNBILL: 100% ( 5/ 5)
# Test Accuracy of HORNED GUAN: 100% ( 5/ 5)
# Test Accuracy of HORNED LARK: 100% ( 5/ 5)
# Test Accuracy of HORNED SUNGEM: 100% ( 5/ 5)
# Test Accuracy of HOUSE FINCH: 80% ( 4/ 5)
# Test Accuracy of HOUSE SPARROW: 100% ( 5/ 5)
# Test Accuracy of HYACINTH MACAW: 100% ( 5/ 5)
# Test Accuracy of IMPERIAL SHAQ: 100% ( 5/ 5)
# Test Accuracy of INCA TERN: 100% ( 5/ 5)
# Test Accuracy of INDIAN BUSTARD: 100% ( 5/ 5)
# Test Accuracy of INDIAN PITTA: 100% ( 5/ 5)
# Test Accuracy of INDIAN ROLLER: 100% ( 5/ 5)
# Test Accuracy of INDIGO BUNTING: 100% ( 5/ 5)
# Test Accuracy of   IWI: 100% ( 5/ 5)
# Test Accuracy of JABIRU: 100% ( 5/ 5)
# Test Accuracy of JAVA SPARROW: 100% ( 5/ 5)
# Test Accuracy of  KAGU: 100% ( 5/ 5)
# Test Accuracy of KAKAPO: 100% ( 5/ 5)
# Test Accuracy of KILLDEAR: 100% ( 5/ 5)
# Test Accuracy of KING VULTURE: 100% ( 5/ 5)
# Test Accuracy of  KIWI: 100% ( 5/ 5)
# Test Accuracy of KOOKABURRA: 100% ( 5/ 5)
# Test Accuracy of LARK BUNTING: 100% ( 5/ 5)
# Test Accuracy of LAZULI BUNTING: 80% ( 4/ 5)
# Test Accuracy of LILAC ROLLER: 100% ( 5/ 5)
# Test Accuracy of LONG-EARED OWL: 80% ( 4/ 5)
# Test Accuracy of MAGPIE GOOSE: 80% ( 4/ 5)
# Test Accuracy of MALABAR HORNBILL: 100% ( 5/ 5)
# Test Accuracy of MALACHITE KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of MALAGASY WHITE EYE: 100% ( 5/ 5)
# Test Accuracy of MALEO: 100% ( 5/ 5)
# Test Accuracy of MALLARD DUCK: 80% ( 4/ 5)
# Test Accuracy of MANDRIN DUCK: 100% ( 5/ 5)
# Test Accuracy of MANGROVE CUCKOO: 80% ( 4/ 5)
# Test Accuracy of MARABOU STORK: 100% ( 5/ 5)
# Test Accuracy of MASKED BOOBY: 80% ( 4/ 5)
# Test Accuracy of MASKED LAPWING: 80% ( 4/ 5)
# Test Accuracy of MIKADO  PHEASANT: 100% ( 5/ 5)
# Test Accuracy of MOURNING DOVE: 100% ( 5/ 5)
# Test Accuracy of  MYNA: 100% ( 5/ 5)
# Test Accuracy of NICOBAR PIGEON: 100% ( 5/ 5)
# Test Accuracy of NOISY FRIARBIRD: 100% ( 5/ 5)
# Test Accuracy of NORTHERN CARDINAL: 80% ( 4/ 5)
# Test Accuracy of NORTHERN FLICKER: 100% ( 5/ 5)
# Test Accuracy of NORTHERN FULMAR: 80% ( 4/ 5)
# Test Accuracy of NORTHERN GANNET: 80% ( 4/ 5)
# Test Accuracy of NORTHERN GOSHAWK: 80% ( 4/ 5)
# Test Accuracy of NORTHERN JACANA: 100% ( 5/ 5)
# Test Accuracy of NORTHERN MOCKINGBIRD: 100% ( 5/ 5)
# Test Accuracy of NORTHERN PARULA: 100% ( 5/ 5)
# Test Accuracy of NORTHERN RED BISHOP: 100% ( 5/ 5)
# Test Accuracy of NORTHERN SHOVELER: 100% ( 5/ 5)
# Test Accuracy of OCELLATED TURKEY: 100% ( 5/ 5)
# Test Accuracy of OKINAWA RAIL: 100% ( 5/ 5)
# Test Accuracy of ORANGE BRESTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of ORIENTAL BAY OWL: 100% ( 5/ 5)
# Test Accuracy of OSPREY: 80% ( 4/ 5)
# Test Accuracy of OSTRICH: 100% ( 5/ 5)
# Test Accuracy of OVENBIRD: 100% ( 5/ 5)
# Test Accuracy of OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of PAINTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of PALILA: 100% ( 5/ 5)
# Test Accuracy of PARADISE TANAGER: 100% ( 5/ 5)
# Test Accuracy of PARAKETT  AKULET: 100% ( 5/ 5)
# Test Accuracy of PARUS MAJOR: 100% ( 5/ 5)
# Test Accuracy of PATAGONIAN SIERRA FINCH: 100% ( 5/ 5)
# Test Accuracy of PEACOCK: 100% ( 5/ 5)
# Test Accuracy of PELICAN: 80% ( 4/ 5)
# Test Accuracy of PEREGRINE FALCON: 100% ( 5/ 5)
# Test Accuracy of PHILIPPINE EAGLE: 100% ( 5/ 5)
# Test Accuracy of PINK ROBIN: 100% ( 5/ 5)
# Test Accuracy of POMARINE JAEGER: 100% ( 5/ 5)
# Test Accuracy of PUFFIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE FINCH: 100% ( 5/ 5)
# Test Accuracy of PURPLE GALLINULE: 100% ( 5/ 5)
# Test Accuracy of PURPLE MARTIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE SWAMPHEN: 100% ( 5/ 5)
# Test Accuracy of PYGMY KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of QUETZAL: 100% ( 5/ 5)
# Test Accuracy of RAINBOW LORIKEET: 100% ( 5/ 5)
# Test Accuracy of RAZORBILL: 100% ( 5/ 5)
# Test Accuracy of RED BEARDED BEE EATER: 100% ( 5/ 5)
# Test Accuracy of RED BELLIED PITTA: 100% ( 5/ 5)
# Test Accuracy of RED BROWED FINCH: 100% ( 5/ 5)
# Test Accuracy of RED FACED CORMORANT: 100% ( 5/ 5)
# Test Accuracy of RED FACED WARBLER: 80% ( 4/ 5)
# Test Accuracy of RED FODY: 100% ( 5/ 5)
# Test Accuracy of RED HEADED DUCK: 100% ( 5/ 5)
# Test Accuracy of RED HEADED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of RED HONEY CREEPER: 100% ( 5/ 5)
# Test Accuracy of RED NAPED TROGON: 100% ( 5/ 5)
# Test Accuracy of RED TAILED HAWK: 100% ( 5/ 5)
# Test Accuracy of RED TAILED THRUSH: 80% ( 4/ 5)
# Test Accuracy of RED WINGED BLACKBIRD: 80% ( 4/ 5)
# Test Accuracy of RED WISKERED BULBUL: 100% ( 5/ 5)
# Test Accuracy of REGENT BOWERBIRD: 80% ( 4/ 5)
# Test Accuracy of RING-NECKED PHEASANT: 100% ( 5/ 5)
# Test Accuracy of ROADRUNNER: 100% ( 5/ 5)
# Test Accuracy of ROBIN: 100% ( 5/ 5)
# Test Accuracy of ROCK DOVE: 100% ( 5/ 5)
# Test Accuracy of ROSY FACED LOVEBIRD: 100% ( 5/ 5)
# Test Accuracy of ROUGH LEG BUZZARD: 100% ( 5/ 5)
# Test Accuracy of ROYAL FLYCATCHER: 100% ( 5/ 5)
# Test Accuracy of RUBY THROATED HUMMINGBIRD: 80% ( 4/ 5)
# Test Accuracy of RUDY KINGFISHER: 60% ( 3/ 5)
# Test Accuracy of RUFOUS KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of RUFUOS MOTMOT: 100% ( 5/ 5)
# Test Accuracy of SAMATRAN THRUSH: 80% ( 4/ 5)
# Test Accuracy of SAND MARTIN: 100% ( 5/ 5)
# Test Accuracy of SANDHILL CRANE: 80% ( 4/ 5)
# Test Accuracy of SATYR TRAGOPAN: 100% ( 5/ 5)
# Test Accuracy of SCARLET CROWNED FRUIT DOVE: 100% ( 5/ 5)
# Test Accuracy of SCARLET IBIS: 100% ( 5/ 5)
# Test Accuracy of SCARLET MACAW: 100% ( 5/ 5)
# Test Accuracy of SCARLET TANAGER: 100% ( 5/ 5)
# Test Accuracy of SHOEBILL: 100% ( 5/ 5)
# Test Accuracy of SHORT BILLED DOWITCHER: 100% ( 5/ 5)
# Test Accuracy of SMITHS LONGSPUR: 100% ( 5/ 5)
# Test Accuracy of SNOWY EGRET: 100% ( 5/ 5)
# Test Accuracy of SNOWY OWL: 100% ( 5/ 5)
# Test Accuracy of  SORA: 100% ( 5/ 5)
# Test Accuracy of SPANGLED COTINGA: 100% ( 5/ 5)
# Test Accuracy of SPLENDID WREN: 60% ( 3/ 5)
# Test Accuracy of SPOON BILED SANDPIPER: 100% ( 5/ 5)
# Test Accuracy of SPOONBILL: 100% ( 5/ 5)
# Test Accuracy of SPOTTED CATBIRD: 100% ( 5/ 5)
# Test Accuracy of SRI LANKA BLUE MAGPIE: 100% ( 5/ 5)
# Test Accuracy of STEAMER DUCK: 100% ( 5/ 5)
# Test Accuracy of STORK BILLED KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of STRAWBERRY FINCH: 100% ( 5/ 5)
# Test Accuracy of STRIPED OWL: 100% ( 5/ 5)
# Test Accuracy of STRIPPED MANAKIN: 100% ( 5/ 5)
# Test Accuracy of STRIPPED SWALLOW: 100% ( 5/ 5)
# Test Accuracy of SUPERB STARLING: 100% ( 5/ 5)
# Test Accuracy of SWINHOES PHEASANT: 100% ( 5/ 5)
# Test Accuracy of TAIWAN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of TAKAHE: 80% ( 4/ 5)
# Test Accuracy of TASMANIAN HEN: 100% ( 5/ 5)
# Test Accuracy of TEAL DUCK: 80% ( 4/ 5)
# Test Accuracy of TIT MOUSE: 100% ( 5/ 5)
# Test Accuracy of TOUCHAN: 100% ( 5/ 5)
# Test Accuracy of TOWNSENDS WARBLER: 100% ( 5/ 5)
# Test Accuracy of TREE SWALLOW: 40% ( 2/ 5)
# Test Accuracy of TROPICAL KINGBIRD: 40% ( 2/ 5)
# Test Accuracy of TRUMPTER SWAN: 100% ( 5/ 5)
# Test Accuracy of TURKEY VULTURE: 100% ( 5/ 5)
# Test Accuracy of TURQUOISE MOTMOT: 100% ( 5/ 5)
# Test Accuracy of UMBRELLA BIRD: 100% ( 5/ 5)
# Test Accuracy of VARIED THRUSH: 100% ( 5/ 5)
# Test Accuracy of VENEZUELIAN TROUPIAL: 100% ( 5/ 5)
# Test Accuracy of VERMILION FLYCATHER: 100% ( 5/ 5)
# Test Accuracy of VICTORIA CROWNED PIGEON: 80% ( 4/ 5)
# Test Accuracy of VIOLET GREEN SWALLOW: 80% ( 4/ 5)
# Test Accuracy of VULTURINE GUINEAFOWL: 100% ( 5/ 5)
# Test Accuracy of WALL CREAPER: 100% ( 5/ 5)
# Test Accuracy of WATTLED CURASSOW: 80% ( 4/ 5)
# Test Accuracy of WATTLED LAPWING: 100% ( 5/ 5)
# Test Accuracy of WHIMBREL: 100% ( 5/ 5)
# Test Accuracy of WHITE BROWED CRAKE: 100% ( 5/ 5)
# Test Accuracy of WHITE CHEEKED TURACO: 60% ( 3/ 5)
# Test Accuracy of WHITE NECKED RAVEN: 100% ( 5/ 5)
# Test Accuracy of WHITE TAILED TROPIC: 100% ( 5/ 5)
# Test Accuracy of WHITE THROATED BEE EATER: 100% ( 5/ 5)
# Test Accuracy of WILD TURKEY: 100% ( 5/ 5)
# Test Accuracy of WILSONS BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of WOOD DUCK: 100% ( 5/ 5)
# Test Accuracy of YELLOW BELLIED FLOWERPECKER: 80% ( 4/ 5)
# Test Accuracy of YELLOW CACIQUE: 80% ( 4/ 5)
# Test Accuracy of YELLOW HEADED BLACKBIRD: 80% ( 4/ 5)
# Test Loss: 0.224255
#
#
# Test Accuracy (Overall): 93% (1644/1750)

# %% [markdown]
# > Benchmark Model -- ResNet 50

# %% [markdown]
# Resnet-50 has 50 CNN layer, which use of 3-layer bottleneck blocks

# %%
from torchvision import models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model = models.resnet50(pretrained=True)

# turn training false for all layers, other than fc layer
for param in base_model.parameters():
    param.requires_grad = False
    
num_ftrs = base_model.fc.in_features
base_model.fc = nn.Linear(num_ftrs, len(classes))
base_model = base_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(base_model.parameters(), lr = 0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
summary(base_model, (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                  [-1, 350]         717,150
# ================================================================
# Total params: 24,225,182
# Trainable params: 717,150
# Non-trainable params: 23,508,032
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 92.41
# Estimated Total Size (MB): 379.54
# ----------------------------------------------------------------

# %%
train(10, base_model, train_loader, optimizer, criterion, valid_loader)
# Out:
# Epoch:  1
#
# Valid Accuracy: 84%
# Train Loss = 1.6601
# Valid Loss = 0.5384
# Epoch:  2
#
# Valid Accuracy: 88%
# Train Loss = 0.7783
# Valid Loss = 0.4271
# Epoch:  3
#
# Valid Accuracy: 89%
# Train Loss = 0.6524
# Valid Loss = 0.4019
# Epoch:  4
#
# Valid Accuracy: 90%
# Train Loss = 0.5597
# Valid Loss = 0.4331
# Epoch:  5
#
# Valid Accuracy: 90%
# Train Loss = 0.5296
# Valid Loss = 0.4303
# Epoch:  6
#
# Valid Accuracy: 91%
# Train Loss = 0.474
# Valid Loss = 0.3661
# Epoch:  7
#
# Valid Accuracy: 90%
# Train Loss = 0.4497
# Valid Loss = 0.4456
# Epoch:  8
#
# Valid Accuracy: 90%
# Train Loss = 0.4178
# Valid Loss = 0.4561
# Epoch:  9
#
# Valid Accuracy: 92%
# Train Loss = 0.3992
# Valid Loss = 0.3603
# Epoch:  10
#
# Valid Accuracy: 91%
# Train Loss = 0.3818
# Valid Loss = 0.4493

# %%
test(classes, base_model, test_loader, criterion)
# Out:
# Test Accuracy of ABBOTTS BABBLER: 60% ( 3/ 5)
# Test Accuracy of ABBOTTS BOOBY:  0% ( 0/ 5)
# Test Accuracy of ABYSSINIAN GROUND HORNBILL: 100% ( 5/ 5)
# Test Accuracy of AFRICAN CROWNED CRANE: 100% ( 5/ 5)
# Test Accuracy of AFRICAN EMERALD CUCKOO: 100% ( 5/ 5)
# Test Accuracy of AFRICAN FIREFINCH: 80% ( 4/ 5)
# Test Accuracy of AFRICAN OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of ALBATROSS: 100% ( 5/ 5)
# Test Accuracy of ALBERTS TOWHEE: 100% ( 5/ 5)
# Test Accuracy of ALEXANDRINE PARAKEET: 60% ( 3/ 5)
# Test Accuracy of ALPINE CHOUGH: 60% ( 3/ 5)
# Test Accuracy of ALTAMIRA YELLOWTHROAT: 60% ( 3/ 5)
# Test Accuracy of AMERICAN AVOCET: 100% ( 5/ 5)
# Test Accuracy of AMERICAN BITTERN: 100% ( 5/ 5)
# Test Accuracy of AMERICAN COOT: 100% ( 5/ 5)
# Test Accuracy of AMERICAN GOLDFINCH: 100% ( 5/ 5)
# Test Accuracy of AMERICAN KESTREL: 100% ( 5/ 5)
# Test Accuracy of AMERICAN PIPIT: 80% ( 4/ 5)
# Test Accuracy of AMERICAN REDSTART: 80% ( 4/ 5)
# Test Accuracy of AMETHYST WOODSTAR: 100% ( 5/ 5)
# Test Accuracy of ANDEAN GOOSE: 80% ( 4/ 5)
# Test Accuracy of ANDEAN LAPWING: 100% ( 5/ 5)
# Test Accuracy of ANDEAN SISKIN: 40% ( 2/ 5)
# Test Accuracy of ANHINGA: 100% ( 5/ 5)
# Test Accuracy of ANIANIAU: 80% ( 4/ 5)
# Test Accuracy of ANNAS HUMMINGBIRD: 100% ( 5/ 5)
# Test Accuracy of ANTBIRD: 80% ( 4/ 5)
# Test Accuracy of ANTILLEAN EUPHONIA: 80% ( 4/ 5)
# Test Accuracy of APAPANE: 80% ( 4/ 5)
# Test Accuracy of APOSTLEBIRD: 80% ( 4/ 5)
# Test Accuracy of ARARIPE MANAKIN: 100% ( 5/ 5)
# Test Accuracy of ASHY THRUSHBIRD: 80% ( 4/ 5)
# Test Accuracy of ASIAN CRESTED IBIS: 100% ( 5/ 5)
# Test Accuracy of AZURE JAY: 80% ( 4/ 5)
# Test Accuracy of AZURE TANAGER: 100% ( 5/ 5)
# Test Accuracy of AZURE TIT: 60% ( 3/ 5)
# Test Accuracy of BAIKAL TEAL: 100% ( 5/ 5)
# Test Accuracy of BALD EAGLE: 100% ( 5/ 5)
# Test Accuracy of BALD IBIS: 100% ( 5/ 5)
# Test Accuracy of BALI STARLING: 100% ( 5/ 5)
# Test Accuracy of BALTIMORE ORIOLE: 80% ( 4/ 5)
# Test Accuracy of BANANAQUIT: 100% ( 5/ 5)
# Test Accuracy of BAND TAILED GUAN: 100% ( 5/ 5)
# Test Accuracy of BANDED BROADBILL: 80% ( 4/ 5)
# Test Accuracy of BANDED PITA: 100% ( 5/ 5)
# Test Accuracy of BANDED STILT: 100% ( 5/ 5)
# Test Accuracy of BAR-TAILED GODWIT: 100% ( 5/ 5)
# Test Accuracy of BARN OWL: 100% ( 5/ 5)
# Test Accuracy of BARN SWALLOW: 100% ( 5/ 5)
# Test Accuracy of BARRED PUFFBIRD: 80% ( 4/ 5)
# Test Accuracy of BARROWS GOLDENEYE: 80% ( 4/ 5)
# Test Accuracy of BAY-BREASTED WARBLER: 100% ( 5/ 5)
# Test Accuracy of BEARDED BARBET: 100% ( 5/ 5)
# Test Accuracy of BEARDED BELLBIRD: 100% ( 5/ 5)
# Test Accuracy of BEARDED REEDLING: 100% ( 5/ 5)
# Test Accuracy of BELTED KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of BLACK & YELLOW  BROADBILL: 100% ( 5/ 5)
# Test Accuracy of BLACK BAZA: 80% ( 4/ 5)
# Test Accuracy of BLACK FRANCOLIN: 80% ( 4/ 5)
# Test Accuracy of BLACK SKIMMER: 80% ( 4/ 5)
# Test Accuracy of BLACK SWAN: 100% ( 5/ 5)
# Test Accuracy of BLACK TAIL CRAKE: 80% ( 4/ 5)
# Test Accuracy of BLACK THROATED BUSHTIT: 100% ( 5/ 5)
# Test Accuracy of BLACK THROATED WARBLER: 80% ( 4/ 5)
# Test Accuracy of BLACK VULTURE: 100% ( 5/ 5)
# Test Accuracy of BLACK-CAPPED CHICKADEE: 100% ( 5/ 5)
# Test Accuracy of BLACK-NECKED GREBE: 100% ( 5/ 5)
# Test Accuracy of BLACK-THROATED SPARROW: 100% ( 5/ 5)
# Test Accuracy of BLACKBURNIAM WARBLER: 80% ( 4/ 5)
# Test Accuracy of BLONDE CRESTED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of BLUE COAU: 40% ( 2/ 5)
# Test Accuracy of BLUE GROUSE: 100% ( 5/ 5)
# Test Accuracy of BLUE HERON: 100% ( 5/ 5)
# Test Accuracy of BLUE THROATED TOUCANET: 100% ( 5/ 5)
# Test Accuracy of BOBOLINK: 100% ( 5/ 5)
# Test Accuracy of BORNEAN BRISTLEHEAD: 100% ( 5/ 5)
# Test Accuracy of BORNEAN LEAFBIRD: 20% ( 1/ 5)
# Test Accuracy of BORNEAN PHEASANT: 80% ( 4/ 5)
# Test Accuracy of BRANDT CORMARANT: 100% ( 5/ 5)
# Test Accuracy of BROWN CREPPER: 100% ( 5/ 5)
# Test Accuracy of BROWN NOODY: 100% ( 5/ 5)
# Test Accuracy of BROWN THRASHER: 100% ( 5/ 5)
# Test Accuracy of BULWERS PHEASANT: 100% ( 5/ 5)
# Test Accuracy of BUSH TURKEY: 100% ( 5/ 5)
# Test Accuracy of CACTUS WREN: 80% ( 4/ 5)
# Test Accuracy of CALIFORNIA CONDOR: 100% ( 5/ 5)
# Test Accuracy of CALIFORNIA GULL: 80% ( 4/ 5)
# Test Accuracy of CALIFORNIA QUAIL: 100% ( 5/ 5)
# Test Accuracy of CANARY: 100% ( 5/ 5)
# Test Accuracy of CAPE GLOSSY STARLING: 100% ( 5/ 5)
# Test Accuracy of CAPE MAY WARBLER: 80% ( 4/ 5)
# Test Accuracy of CAPPED HERON: 60% ( 3/ 5)
# Test Accuracy of CAPUCHINBIRD: 100% ( 5/ 5)
# Test Accuracy of CARMINE BEE-EATER: 60% ( 3/ 5)
# Test Accuracy of CASPIAN TERN: 100% ( 5/ 5)
# Test Accuracy of CASSOWARY: 100% ( 5/ 5)
# Test Accuracy of CEDAR WAXWING: 100% ( 5/ 5)
# Test Accuracy of CERULEAN WARBLER: 100% ( 5/ 5)
# Test Accuracy of CHARA DE COLLAR: 100% ( 5/ 5)
# Test Accuracy of CHESTNET BELLIED EUPHONIA: 100% ( 5/ 5)
# Test Accuracy of CHIPPING SPARROW: 60% ( 3/ 5)
# Test Accuracy of CHUKAR PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of CINNAMON TEAL: 100% ( 5/ 5)
# Test Accuracy of CLARKS NUTCRACKER: 100% ( 5/ 5)
# Test Accuracy of COCK OF THE  ROCK: 100% ( 5/ 5)
# Test Accuracy of COCKATOO: 100% ( 5/ 5)
# Test Accuracy of COLLARED ARACARI: 100% ( 5/ 5)
# Test Accuracy of COMMON FIRECREST: 100% ( 5/ 5)
# Test Accuracy of COMMON GRACKLE: 100% ( 5/ 5)
# Test Accuracy of COMMON HOUSE MARTIN: 80% ( 4/ 5)
# Test Accuracy of COMMON LOON: 100% ( 5/ 5)
# Test Accuracy of COMMON POORWILL: 100% ( 5/ 5)
# Test Accuracy of COMMON STARLING: 100% ( 5/ 5)
# Test Accuracy of CRESTED AUKLET: 100% ( 5/ 5)
# Test Accuracy of CRESTED CARACARA: 60% ( 3/ 5)
# Test Accuracy of CRESTED NUTHATCH: 80% ( 4/ 5)
# Test Accuracy of CRIMSON SUNBIRD: 100% ( 5/ 5)
# Test Accuracy of  CROW: 100% ( 5/ 5)
# Test Accuracy of CROWNED PIGEON: 80% ( 4/ 5)
# Test Accuracy of CUBAN TODY: 100% ( 5/ 5)
# Test Accuracy of CUBAN TROGON: 80% ( 4/ 5)
# Test Accuracy of CURL CRESTED ARACURI: 100% ( 5/ 5)
# Test Accuracy of D-ARNAUDS BARBET: 100% ( 5/ 5)
# Test Accuracy of DARK EYED JUNCO: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BARRED FINCH: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BRESTED CORMARANT: 100% ( 5/ 5)
# Test Accuracy of DOWNY WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of EASTERN BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of EASTERN MEADOWLARK: 100% ( 5/ 5)
# Test Accuracy of EASTERN ROSELLA: 100% ( 5/ 5)
# Test Accuracy of EASTERN TOWEE: 100% ( 5/ 5)
# Test Accuracy of ELEGANT TROGON: 100% ( 5/ 5)
# Test Accuracy of ELLIOTS  PHEASANT:  0% ( 0/ 5)
# Test Accuracy of EMPEROR PENGUIN: 100% ( 5/ 5)
# Test Accuracy of   EMU: 100% ( 5/ 5)
# Test Accuracy of ENGGANO MYNA: 100% ( 5/ 5)
# Test Accuracy of EURASIAN GOLDEN ORIOLE: 100% ( 5/ 5)
# Test Accuracy of EURASIAN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of EVENING GROSBEAK: 100% ( 5/ 5)
# Test Accuracy of FAIRY BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of FIRE TAILLED MYZORNIS: 100% ( 5/ 5)
# Test Accuracy of FLAME TANAGER: 100% ( 5/ 5)
# Test Accuracy of FLAMINGO: 100% ( 5/ 5)
# Test Accuracy of FRIGATE: 100% ( 5/ 5)
# Test Accuracy of GAMBELS QUAIL: 100% ( 5/ 5)
# Test Accuracy of GANG GANG COCKATOO: 100% ( 5/ 5)
# Test Accuracy of GILA WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of GILDED FLICKER: 80% ( 4/ 5)
# Test Accuracy of GLOSSY IBIS: 100% ( 5/ 5)
# Test Accuracy of GO AWAY BIRD: 100% ( 5/ 5)
# Test Accuracy of GOLD WING WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHEEKED WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHLOROPHONIA: 100% ( 5/ 5)
# Test Accuracy of GOLDEN EAGLE: 80% ( 4/ 5)
# Test Accuracy of GOLDEN PHEASANT: 100% ( 5/ 5)
# Test Accuracy of GOLDEN PIPIT: 100% ( 5/ 5)
# Test Accuracy of GOULDIAN FINCH: 100% ( 5/ 5)
# Test Accuracy of GRAY CATBIRD: 40% ( 2/ 5)
# Test Accuracy of GRAY KINGBIRD: 80% ( 4/ 5)
# Test Accuracy of GRAY PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of GREAT GRAY OWL: 100% ( 5/ 5)
# Test Accuracy of GREAT KISKADEE: 100% ( 5/ 5)
# Test Accuracy of GREAT POTOO: 80% ( 4/ 5)
# Test Accuracy of GREATOR SAGE GROUSE: 100% ( 5/ 5)
# Test Accuracy of GREEN BROADBILL: 100% ( 5/ 5)
# Test Accuracy of GREEN JAY: 100% ( 5/ 5)
# Test Accuracy of GREEN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of GREY PLOVER: 100% ( 5/ 5)
# Test Accuracy of GROVED BILLED ANI: 60% ( 3/ 5)
# Test Accuracy of GUINEA TURACO: 100% ( 5/ 5)
# Test Accuracy of GUINEAFOWL: 100% ( 5/ 5)
# Test Accuracy of GYRFALCON: 100% ( 5/ 5)
# Test Accuracy of HARLEQUIN DUCK: 100% ( 5/ 5)
# Test Accuracy of HARPY EAGLE: 100% ( 5/ 5)
# Test Accuracy of HAWAIIAN GOOSE: 100% ( 5/ 5)
# Test Accuracy of HELMET VANGA: 100% ( 5/ 5)
# Test Accuracy of HIMALAYAN MONAL: 100% ( 5/ 5)
# Test Accuracy of HOATZIN: 100% ( 5/ 5)
# Test Accuracy of HOODED MERGANSER: 80% ( 4/ 5)
# Test Accuracy of HOOPOES: 100% ( 5/ 5)
# Test Accuracy of HORNBILL: 100% ( 5/ 5)
# Test Accuracy of HORNED GUAN: 100% ( 5/ 5)
# Test Accuracy of HORNED LARK: 100% ( 5/ 5)
# Test Accuracy of HORNED SUNGEM: 100% ( 5/ 5)
# Test Accuracy of HOUSE FINCH: 100% ( 5/ 5)
# Test Accuracy of HOUSE SPARROW: 100% ( 5/ 5)
# Test Accuracy of HYACINTH MACAW: 100% ( 5/ 5)
# Test Accuracy of IMPERIAL SHAQ: 60% ( 3/ 5)
# Test Accuracy of INCA TERN: 100% ( 5/ 5)
# Test Accuracy of INDIAN BUSTARD: 100% ( 5/ 5)
# Test Accuracy of INDIAN PITTA: 100% ( 5/ 5)
# Test Accuracy of INDIAN ROLLER: 100% ( 5/ 5)
# Test Accuracy of INDIGO BUNTING: 100% ( 5/ 5)
# Test Accuracy of   IWI: 100% ( 5/ 5)
# Test Accuracy of JABIRU: 100% ( 5/ 5)
# Test Accuracy of JAVA SPARROW: 100% ( 5/ 5)
# Test Accuracy of  KAGU: 100% ( 5/ 5)
# Test Accuracy of KAKAPO: 100% ( 5/ 5)
# Test Accuracy of KILLDEAR: 80% ( 4/ 5)
# Test Accuracy of KING VULTURE: 100% ( 5/ 5)
# Test Accuracy of  KIWI: 100% ( 5/ 5)
# Test Accuracy of KOOKABURRA: 100% ( 5/ 5)
# Test Accuracy of LARK BUNTING: 100% ( 5/ 5)
# Test Accuracy of LAZULI BUNTING: 80% ( 4/ 5)
# Test Accuracy of LILAC ROLLER: 100% ( 5/ 5)
# Test Accuracy of LONG-EARED OWL: 60% ( 3/ 5)
# Test Accuracy of MAGPIE GOOSE: 100% ( 5/ 5)
# Test Accuracy of MALABAR HORNBILL: 100% ( 5/ 5)
# Test Accuracy of MALACHITE KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of MALAGASY WHITE EYE: 80% ( 4/ 5)
# Test Accuracy of MALEO: 100% ( 5/ 5)
# Test Accuracy of MALLARD DUCK: 100% ( 5/ 5)
# Test Accuracy of MANDRIN DUCK: 100% ( 5/ 5)
# Test Accuracy of MANGROVE CUCKOO: 80% ( 4/ 5)
# Test Accuracy of MARABOU STORK: 100% ( 5/ 5)
# Test Accuracy of MASKED BOOBY: 60% ( 3/ 5)
# Test Accuracy of MASKED LAPWING: 100% ( 5/ 5)
# Test Accuracy of MIKADO  PHEASANT: 100% ( 5/ 5)
# Test Accuracy of MOURNING DOVE: 100% ( 5/ 5)
# Test Accuracy of  MYNA: 100% ( 5/ 5)
# Test Accuracy of NICOBAR PIGEON: 100% ( 5/ 5)
# Test Accuracy of NOISY FRIARBIRD: 100% ( 5/ 5)
# Test Accuracy of NORTHERN CARDINAL: 80% ( 4/ 5)
# Test Accuracy of NORTHERN FLICKER: 100% ( 5/ 5)
# Test Accuracy of NORTHERN FULMAR: 100% ( 5/ 5)
# Test Accuracy of NORTHERN GANNET: 100% ( 5/ 5)
# Test Accuracy of NORTHERN GOSHAWK: 100% ( 5/ 5)
# Test Accuracy of NORTHERN JACANA: 80% ( 4/ 5)
# Test Accuracy of NORTHERN MOCKINGBIRD: 80% ( 4/ 5)
# Test Accuracy of NORTHERN PARULA: 100% ( 5/ 5)
# Test Accuracy of NORTHERN RED BISHOP: 100% ( 5/ 5)
# Test Accuracy of NORTHERN SHOVELER: 100% ( 5/ 5)
# Test Accuracy of OCELLATED TURKEY: 100% ( 5/ 5)
# Test Accuracy of OKINAWA RAIL: 100% ( 5/ 5)
# Test Accuracy of ORANGE BRESTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of ORIENTAL BAY OWL: 100% ( 5/ 5)
# Test Accuracy of OSPREY: 100% ( 5/ 5)
# Test Accuracy of OSTRICH: 100% ( 5/ 5)
# Test Accuracy of OVENBIRD: 80% ( 4/ 5)
# Test Accuracy of OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of PAINTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of PALILA: 100% ( 5/ 5)
# Test Accuracy of PARADISE TANAGER: 100% ( 5/ 5)
# Test Accuracy of PARAKETT  AKULET: 80% ( 4/ 5)
# Test Accuracy of PARUS MAJOR: 100% ( 5/ 5)
# Test Accuracy of PATAGONIAN SIERRA FINCH: 80% ( 4/ 5)
# Test Accuracy of PEACOCK: 100% ( 5/ 5)
# Test Accuracy of PELICAN: 80% ( 4/ 5)
# Test Accuracy of PEREGRINE FALCON: 100% ( 5/ 5)
# Test Accuracy of PHILIPPINE EAGLE: 100% ( 5/ 5)
# Test Accuracy of PINK ROBIN: 100% ( 5/ 5)
# Test Accuracy of POMARINE JAEGER: 100% ( 5/ 5)
# Test Accuracy of PUFFIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE FINCH: 100% ( 5/ 5)
# Test Accuracy of PURPLE GALLINULE: 100% ( 5/ 5)
# Test Accuracy of PURPLE MARTIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE SWAMPHEN: 80% ( 4/ 5)
# Test Accuracy of PYGMY KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of QUETZAL: 100% ( 5/ 5)
# Test Accuracy of RAINBOW LORIKEET: 100% ( 5/ 5)
# Test Accuracy of RAZORBILL: 100% ( 5/ 5)
# Test Accuracy of RED BEARDED BEE EATER: 100% ( 5/ 5)
# Test Accuracy of RED BELLIED PITTA: 100% ( 5/ 5)
# Test Accuracy of RED BROWED FINCH: 100% ( 5/ 5)
# Test Accuracy of RED FACED CORMORANT: 80% ( 4/ 5)
# Test Accuracy of RED FACED WARBLER: 100% ( 5/ 5)
# Test Accuracy of RED FODY: 100% ( 5/ 5)
# Test Accuracy of RED HEADED DUCK: 100% ( 5/ 5)
# Test Accuracy of RED HEADED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of RED HONEY CREEPER: 100% ( 5/ 5)
# Test Accuracy of RED NAPED TROGON: 100% ( 5/ 5)
# Test Accuracy of RED TAILED HAWK: 80% ( 4/ 5)
# Test Accuracy of RED TAILED THRUSH: 100% ( 5/ 5)
# Test Accuracy of RED WINGED BLACKBIRD: 100% ( 5/ 5)
# Test Accuracy of RED WISKERED BULBUL: 100% ( 5/ 5)
# Test Accuracy of REGENT BOWERBIRD: 100% ( 5/ 5)
# Test Accuracy of RING-NECKED PHEASANT: 100% ( 5/ 5)
# Test Accuracy of ROADRUNNER: 100% ( 5/ 5)
# Test Accuracy of ROBIN: 80% ( 4/ 5)
# Test Accuracy of ROCK DOVE: 80% ( 4/ 5)
# Test Accuracy of ROSY FACED LOVEBIRD: 100% ( 5/ 5)
# Test Accuracy of ROUGH LEG BUZZARD: 100% ( 5/ 5)
# Test Accuracy of ROYAL FLYCATCHER: 100% ( 5/ 5)
# Test Accuracy of RUBY THROATED HUMMINGBIRD: 100% ( 5/ 5)
# Test Accuracy of RUDY KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of RUFOUS KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of RUFUOS MOTMOT: 100% ( 5/ 5)
# Test Accuracy of SAMATRAN THRUSH: 80% ( 4/ 5)
# Test Accuracy of SAND MARTIN: 100% ( 5/ 5)
# Test Accuracy of SANDHILL CRANE: 80% ( 4/ 5)
# Test Accuracy of SATYR TRAGOPAN: 100% ( 5/ 5)
# Test Accuracy of SCARLET CROWNED FRUIT DOVE: 100% ( 5/ 5)
# Test Accuracy of SCARLET IBIS: 100% ( 5/ 5)
# Test Accuracy of SCARLET MACAW: 100% ( 5/ 5)
# Test Accuracy of SCARLET TANAGER: 100% ( 5/ 5)
# Test Accuracy of SHOEBILL: 100% ( 5/ 5)
# Test Accuracy of SHORT BILLED DOWITCHER: 100% ( 5/ 5)
# Test Accuracy of SMITHS LONGSPUR: 100% ( 5/ 5)
# Test Accuracy of SNOWY EGRET: 100% ( 5/ 5)
# Test Accuracy of SNOWY OWL: 100% ( 5/ 5)
# Test Accuracy of  SORA: 80% ( 4/ 5)
# Test Accuracy of SPANGLED COTINGA: 80% ( 4/ 5)
# Test Accuracy of SPLENDID WREN: 100% ( 5/ 5)
# Test Accuracy of SPOON BILED SANDPIPER: 80% ( 4/ 5)
# Test Accuracy of SPOONBILL: 100% ( 5/ 5)
# Test Accuracy of SPOTTED CATBIRD: 100% ( 5/ 5)
# Test Accuracy of SRI LANKA BLUE MAGPIE: 100% ( 5/ 5)
# Test Accuracy of STEAMER DUCK: 100% ( 5/ 5)
# Test Accuracy of STORK BILLED KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of STRAWBERRY FINCH: 100% ( 5/ 5)
# Test Accuracy of STRIPED OWL: 100% ( 5/ 5)
# Test Accuracy of STRIPPED MANAKIN: 100% ( 5/ 5)
# Test Accuracy of STRIPPED SWALLOW: 100% ( 5/ 5)
# Test Accuracy of SUPERB STARLING: 100% ( 5/ 5)
# Test Accuracy of SWINHOES PHEASANT: 100% ( 5/ 5)
# Test Accuracy of TAIWAN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of TAKAHE: 100% ( 5/ 5)
# Test Accuracy of TASMANIAN HEN: 100% ( 5/ 5)
# Test Accuracy of TEAL DUCK: 100% ( 5/ 5)
# Test Accuracy of TIT MOUSE: 100% ( 5/ 5)
# Test Accuracy of TOUCHAN: 100% ( 5/ 5)
# Test Accuracy of TOWNSENDS WARBLER: 80% ( 4/ 5)
# Test Accuracy of TREE SWALLOW: 100% ( 5/ 5)
# Test Accuracy of TROPICAL KINGBIRD: 80% ( 4/ 5)
# Test Accuracy of TRUMPTER SWAN: 100% ( 5/ 5)
# Test Accuracy of TURKEY VULTURE: 80% ( 4/ 5)
# Test Accuracy of TURQUOISE MOTMOT: 100% ( 5/ 5)
# Test Accuracy of UMBRELLA BIRD: 100% ( 5/ 5)
# Test Accuracy of VARIED THRUSH: 100% ( 5/ 5)
# Test Accuracy of VENEZUELIAN TROUPIAL: 100% ( 5/ 5)
# Test Accuracy of VERMILION FLYCATHER: 80% ( 4/ 5)
# Test Accuracy of VICTORIA CROWNED PIGEON: 100% ( 5/ 5)
# Test Accuracy of VIOLET GREEN SWALLOW: 100% ( 5/ 5)
# Test Accuracy of VULTURINE GUINEAFOWL: 100% ( 5/ 5)
# Test Accuracy of WALL CREAPER: 100% ( 5/ 5)
# Test Accuracy of WATTLED CURASSOW: 100% ( 5/ 5)
# Test Accuracy of WATTLED LAPWING: 100% ( 5/ 5)
# Test Accuracy of WHIMBREL: 80% ( 4/ 5)
# Test Accuracy of WHITE BROWED CRAKE: 80% ( 4/ 5)
# Test Accuracy of WHITE CHEEKED TURACO: 60% ( 3/ 5)
# Test Accuracy of WHITE NECKED RAVEN: 100% ( 5/ 5)
# Test Accuracy of WHITE TAILED TROPIC: 100% ( 5/ 5)
# Test Accuracy of WHITE THROATED BEE EATER: 100% ( 5/ 5)
# Test Accuracy of WILD TURKEY: 100% ( 5/ 5)
# Test Accuracy of WILSONS BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of WOOD DUCK: 100% ( 5/ 5)
# Test Accuracy of YELLOW BELLIED FLOWERPECKER: 80% ( 4/ 5)
# Test Accuracy of YELLOW CACIQUE: 100% ( 5/ 5)
# Test Accuracy of YELLOW HEADED BLACKBIRD: 100% ( 5/ 5)
# Test Loss: 0.263727
#
#
# Test Accuracy (Overall): 93% (1634/1750)

# %% [markdown]
# > ResNet 101

# %%
base_model = models.resnet101(pretrained=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# turn training false for all layers, other than fc layer
for param in base_model.parameters():
    param.requires_grad = False
    
num_ftrs = base_model.fc.in_features
base_model.fc = nn.Linear(num_ftrs, len(classes))
base_model = base_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(base_model.parameters(), lr = 0.001)
summary(base_model, (3,224,224))

# %%
train(10, base_model, train_loader, optimizer, criterion, valid_loader)
# Out:
# Epoch:  1
#
# Valid Accuracy: 86%
# Train Loss = 1.5594
# Valid Loss = 0.477
# Epoch:  2
#
# Valid Accuracy: 88%
# Train Loss = 0.7273
# Valid Loss = 0.4242
# Epoch:  3
#
# Valid Accuracy: 89%
# Train Loss = 0.6246
# Valid Loss = 0.3865
# Epoch:  4
#
# Valid Accuracy: 89%
# Train Loss = 0.5418
# Valid Loss = 0.4654
# Epoch:  5
#
# Valid Accuracy: 90%
# Train Loss = 0.4949
# Valid Loss = 0.3587
# Epoch:  6
#
# Valid Accuracy: 90%
# Train Loss = 0.4509
# Valid Loss = 0.4039
# Epoch:  7
#
# Valid Accuracy: 92%
# Train Loss = 0.4315
# Valid Loss = 0.3334
# Epoch:  8
#
# Valid Accuracy: 91%
# Train Loss = 0.411
# Valid Loss = 0.4314
# Epoch:  9
#
# Valid Accuracy: 91%
# Train Loss = 0.3714
# Valid Loss = 0.4015
# Epoch:  10
#
# Valid Accuracy: 93%
# Train Loss = 0.3608
# Valid Loss = 0.3345

# %%
test(classes, base_model, test_loader, criterion)
# Out:
# Test Accuracy of ABBOTTS BABBLER: 100% ( 5/ 5)
# Test Accuracy of ABBOTTS BOOBY: 60% ( 3/ 5)
# Test Accuracy of ABYSSINIAN GROUND HORNBILL: 100% ( 5/ 5)
# Test Accuracy of AFRICAN CROWNED CRANE: 100% ( 5/ 5)
# Test Accuracy of AFRICAN EMERALD CUCKOO: 80% ( 4/ 5)
# Test Accuracy of AFRICAN FIREFINCH: 80% ( 4/ 5)
# Test Accuracy of AFRICAN OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of ALBATROSS: 100% ( 5/ 5)
# Test Accuracy of ALBERTS TOWHEE: 100% ( 5/ 5)
# Test Accuracy of ALEXANDRINE PARAKEET: 100% ( 5/ 5)
# Test Accuracy of ALPINE CHOUGH: 100% ( 5/ 5)
# Test Accuracy of ALTAMIRA YELLOWTHROAT: 20% ( 1/ 5)
# Test Accuracy of AMERICAN AVOCET: 100% ( 5/ 5)
# Test Accuracy of AMERICAN BITTERN: 100% ( 5/ 5)
# Test Accuracy of AMERICAN COOT: 100% ( 5/ 5)
# Test Accuracy of AMERICAN GOLDFINCH: 100% ( 5/ 5)
# Test Accuracy of AMERICAN KESTREL: 100% ( 5/ 5)
# Test Accuracy of AMERICAN PIPIT: 80% ( 4/ 5)
# Test Accuracy of AMERICAN REDSTART: 100% ( 5/ 5)
# Test Accuracy of AMETHYST WOODSTAR: 80% ( 4/ 5)
# Test Accuracy of ANDEAN GOOSE: 80% ( 4/ 5)
# Test Accuracy of ANDEAN LAPWING: 100% ( 5/ 5)
# Test Accuracy of ANDEAN SISKIN:  0% ( 0/ 5)
# Test Accuracy of ANHINGA: 100% ( 5/ 5)
# Test Accuracy of ANIANIAU: 100% ( 5/ 5)
# Test Accuracy of ANNAS HUMMINGBIRD: 100% ( 5/ 5)
# Test Accuracy of ANTBIRD: 80% ( 4/ 5)
# Test Accuracy of ANTILLEAN EUPHONIA: 100% ( 5/ 5)
# Test Accuracy of APAPANE: 100% ( 5/ 5)
# Test Accuracy of APOSTLEBIRD: 80% ( 4/ 5)
# Test Accuracy of ARARIPE MANAKIN: 100% ( 5/ 5)
# Test Accuracy of ASHY THRUSHBIRD: 100% ( 5/ 5)
# Test Accuracy of ASIAN CRESTED IBIS: 100% ( 5/ 5)
# Test Accuracy of AZURE JAY: 100% ( 5/ 5)
# Test Accuracy of AZURE TANAGER: 100% ( 5/ 5)
# Test Accuracy of AZURE TIT: 80% ( 4/ 5)
# Test Accuracy of BAIKAL TEAL: 100% ( 5/ 5)
# Test Accuracy of BALD EAGLE: 100% ( 5/ 5)
# Test Accuracy of BALD IBIS: 100% ( 5/ 5)
# Test Accuracy of BALI STARLING: 100% ( 5/ 5)
# Test Accuracy of BALTIMORE ORIOLE: 40% ( 2/ 5)
# Test Accuracy of BANANAQUIT: 100% ( 5/ 5)
# Test Accuracy of BAND TAILED GUAN: 80% ( 4/ 5)
# Test Accuracy of BANDED BROADBILL: 100% ( 5/ 5)
# Test Accuracy of BANDED PITA: 100% ( 5/ 5)
# Test Accuracy of BANDED STILT: 100% ( 5/ 5)
# Test Accuracy of BAR-TAILED GODWIT: 100% ( 5/ 5)
# Test Accuracy of BARN OWL: 100% ( 5/ 5)
# Test Accuracy of BARN SWALLOW: 100% ( 5/ 5)
# Test Accuracy of BARRED PUFFBIRD: 100% ( 5/ 5)
# Test Accuracy of BARROWS GOLDENEYE: 80% ( 4/ 5)
# Test Accuracy of BAY-BREASTED WARBLER: 100% ( 5/ 5)
# Test Accuracy of BEARDED BARBET: 100% ( 5/ 5)
# Test Accuracy of BEARDED BELLBIRD: 100% ( 5/ 5)
# Test Accuracy of BEARDED REEDLING: 100% ( 5/ 5)
# Test Accuracy of BELTED KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of BLACK & YELLOW  BROADBILL: 100% ( 5/ 5)
# Test Accuracy of BLACK BAZA: 100% ( 5/ 5)
# Test Accuracy of BLACK FRANCOLIN: 80% ( 4/ 5)
# Test Accuracy of BLACK SKIMMER: 100% ( 5/ 5)
# Test Accuracy of BLACK SWAN: 100% ( 5/ 5)
# Test Accuracy of BLACK TAIL CRAKE: 100% ( 5/ 5)
# Test Accuracy of BLACK THROATED BUSHTIT: 100% ( 5/ 5)
# Test Accuracy of BLACK THROATED WARBLER: 100% ( 5/ 5)
# Test Accuracy of BLACK VULTURE: 100% ( 5/ 5)
# Test Accuracy of BLACK-CAPPED CHICKADEE: 100% ( 5/ 5)
# Test Accuracy of BLACK-NECKED GREBE: 100% ( 5/ 5)
# Test Accuracy of BLACK-THROATED SPARROW: 100% ( 5/ 5)
# Test Accuracy of BLACKBURNIAM WARBLER: 100% ( 5/ 5)
# Test Accuracy of BLONDE CRESTED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of BLUE COAU: 100% ( 5/ 5)
# Test Accuracy of BLUE GROUSE: 80% ( 4/ 5)
# Test Accuracy of BLUE HERON: 100% ( 5/ 5)
# Test Accuracy of BLUE THROATED TOUCANET: 100% ( 5/ 5)
# Test Accuracy of BOBOLINK: 100% ( 5/ 5)
# Test Accuracy of BORNEAN BRISTLEHEAD: 100% ( 5/ 5)
# Test Accuracy of BORNEAN LEAFBIRD: 80% ( 4/ 5)
# Test Accuracy of BORNEAN PHEASANT: 100% ( 5/ 5)
# Test Accuracy of BRANDT CORMARANT: 100% ( 5/ 5)
# Test Accuracy of BROWN CREPPER: 100% ( 5/ 5)
# Test Accuracy of BROWN NOODY: 100% ( 5/ 5)
# Test Accuracy of BROWN THRASHER: 100% ( 5/ 5)
# Test Accuracy of BULWERS PHEASANT: 100% ( 5/ 5)
# Test Accuracy of BUSH TURKEY: 80% ( 4/ 5)
# Test Accuracy of CACTUS WREN: 100% ( 5/ 5)
# Test Accuracy of CALIFORNIA CONDOR: 100% ( 5/ 5)
# Test Accuracy of CALIFORNIA GULL: 80% ( 4/ 5)
# Test Accuracy of CALIFORNIA QUAIL: 100% ( 5/ 5)
# Test Accuracy of CANARY: 100% ( 5/ 5)
# Test Accuracy of CAPE GLOSSY STARLING: 100% ( 5/ 5)
# Test Accuracy of CAPE MAY WARBLER: 100% ( 5/ 5)
# Test Accuracy of CAPPED HERON: 80% ( 4/ 5)
# Test Accuracy of CAPUCHINBIRD: 100% ( 5/ 5)
# Test Accuracy of CARMINE BEE-EATER: 80% ( 4/ 5)
# Test Accuracy of CASPIAN TERN: 100% ( 5/ 5)
# Test Accuracy of CASSOWARY: 100% ( 5/ 5)
# Test Accuracy of CEDAR WAXWING: 100% ( 5/ 5)
# Test Accuracy of CERULEAN WARBLER: 100% ( 5/ 5)
# Test Accuracy of CHARA DE COLLAR: 100% ( 5/ 5)
# Test Accuracy of CHESTNET BELLIED EUPHONIA: 100% ( 5/ 5)
# Test Accuracy of CHIPPING SPARROW: 80% ( 4/ 5)
# Test Accuracy of CHUKAR PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of CINNAMON TEAL: 60% ( 3/ 5)
# Test Accuracy of CLARKS NUTCRACKER: 100% ( 5/ 5)
# Test Accuracy of COCK OF THE  ROCK: 100% ( 5/ 5)
# Test Accuracy of COCKATOO: 100% ( 5/ 5)
# Test Accuracy of COLLARED ARACARI: 100% ( 5/ 5)
# Test Accuracy of COMMON FIRECREST: 100% ( 5/ 5)
# Test Accuracy of COMMON GRACKLE: 80% ( 4/ 5)
# Test Accuracy of COMMON HOUSE MARTIN: 80% ( 4/ 5)
# Test Accuracy of COMMON LOON: 100% ( 5/ 5)
# Test Accuracy of COMMON POORWILL: 100% ( 5/ 5)
# Test Accuracy of COMMON STARLING: 100% ( 5/ 5)
# Test Accuracy of CRESTED AUKLET: 100% ( 5/ 5)
# Test Accuracy of CRESTED CARACARA: 100% ( 5/ 5)
# Test Accuracy of CRESTED NUTHATCH: 100% ( 5/ 5)
# Test Accuracy of CRIMSON SUNBIRD: 100% ( 5/ 5)
# Test Accuracy of  CROW: 80% ( 4/ 5)
# Test Accuracy of CROWNED PIGEON: 60% ( 3/ 5)
# Test Accuracy of CUBAN TODY: 100% ( 5/ 5)
# Test Accuracy of CUBAN TROGON: 100% ( 5/ 5)
# Test Accuracy of CURL CRESTED ARACURI: 100% ( 5/ 5)
# Test Accuracy of D-ARNAUDS BARBET: 100% ( 5/ 5)
# Test Accuracy of DARK EYED JUNCO: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BARRED FINCH: 100% ( 5/ 5)
# Test Accuracy of DOUBLE BRESTED CORMARANT: 80% ( 4/ 5)
# Test Accuracy of DOWNY WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of EASTERN BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of EASTERN MEADOWLARK: 100% ( 5/ 5)
# Test Accuracy of EASTERN ROSELLA: 100% ( 5/ 5)
# Test Accuracy of EASTERN TOWEE: 100% ( 5/ 5)
# Test Accuracy of ELEGANT TROGON: 80% ( 4/ 5)
# Test Accuracy of ELLIOTS  PHEASANT: 80% ( 4/ 5)
# Test Accuracy of EMPEROR PENGUIN: 100% ( 5/ 5)
# Test Accuracy of   EMU: 100% ( 5/ 5)
# Test Accuracy of ENGGANO MYNA: 100% ( 5/ 5)
# Test Accuracy of EURASIAN GOLDEN ORIOLE: 100% ( 5/ 5)
# Test Accuracy of EURASIAN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of EVENING GROSBEAK: 100% ( 5/ 5)
# Test Accuracy of FAIRY BLUEBIRD: 100% ( 5/ 5)
# Test Accuracy of FIRE TAILLED MYZORNIS: 100% ( 5/ 5)
# Test Accuracy of FLAME TANAGER: 80% ( 4/ 5)
# Test Accuracy of FLAMINGO: 100% ( 5/ 5)
# Test Accuracy of FRIGATE: 100% ( 5/ 5)
# Test Accuracy of GAMBELS QUAIL: 100% ( 5/ 5)
# Test Accuracy of GANG GANG COCKATOO: 100% ( 5/ 5)
# Test Accuracy of GILA WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of GILDED FLICKER: 100% ( 5/ 5)
# Test Accuracy of GLOSSY IBIS: 100% ( 5/ 5)
# Test Accuracy of GO AWAY BIRD: 100% ( 5/ 5)
# Test Accuracy of GOLD WING WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHEEKED WARBLER: 100% ( 5/ 5)
# Test Accuracy of GOLDEN CHLOROPHONIA: 100% ( 5/ 5)
# Test Accuracy of GOLDEN EAGLE: 80% ( 4/ 5)
# Test Accuracy of GOLDEN PHEASANT: 100% ( 5/ 5)
# Test Accuracy of GOLDEN PIPIT: 80% ( 4/ 5)
# Test Accuracy of GOULDIAN FINCH: 80% ( 4/ 5)
# Test Accuracy of GRAY CATBIRD: 100% ( 5/ 5)
# Test Accuracy of GRAY KINGBIRD: 80% ( 4/ 5)
# Test Accuracy of GRAY PARTRIDGE: 100% ( 5/ 5)
# Test Accuracy of GREAT GRAY OWL: 100% ( 5/ 5)
# Test Accuracy of GREAT KISKADEE: 100% ( 5/ 5)
# Test Accuracy of GREAT POTOO: 80% ( 4/ 5)
# Test Accuracy of GREATOR SAGE GROUSE: 100% ( 5/ 5)
# Test Accuracy of GREEN BROADBILL: 100% ( 5/ 5)
# Test Accuracy of GREEN JAY: 100% ( 5/ 5)
# Test Accuracy of GREEN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of GREY PLOVER: 100% ( 5/ 5)
# Test Accuracy of GROVED BILLED ANI: 100% ( 5/ 5)
# Test Accuracy of GUINEA TURACO: 100% ( 5/ 5)
# Test Accuracy of GUINEAFOWL: 100% ( 5/ 5)
# Test Accuracy of GYRFALCON: 80% ( 4/ 5)
# Test Accuracy of HARLEQUIN DUCK: 100% ( 5/ 5)
# Test Accuracy of HARPY EAGLE: 80% ( 4/ 5)
# Test Accuracy of HAWAIIAN GOOSE: 100% ( 5/ 5)
# Test Accuracy of HELMET VANGA: 100% ( 5/ 5)
# Test Accuracy of HIMALAYAN MONAL: 100% ( 5/ 5)
# Test Accuracy of HOATZIN: 100% ( 5/ 5)
# Test Accuracy of HOODED MERGANSER: 80% ( 4/ 5)
# Test Accuracy of HOOPOES: 100% ( 5/ 5)
# Test Accuracy of HORNBILL: 100% ( 5/ 5)
# Test Accuracy of HORNED GUAN: 100% ( 5/ 5)
# Test Accuracy of HORNED LARK: 100% ( 5/ 5)
# Test Accuracy of HORNED SUNGEM: 100% ( 5/ 5)
# Test Accuracy of HOUSE FINCH: 80% ( 4/ 5)
# Test Accuracy of HOUSE SPARROW: 100% ( 5/ 5)
# Test Accuracy of HYACINTH MACAW: 100% ( 5/ 5)
# Test Accuracy of IMPERIAL SHAQ: 100% ( 5/ 5)
# Test Accuracy of INCA TERN: 100% ( 5/ 5)
# Test Accuracy of INDIAN BUSTARD: 100% ( 5/ 5)
# Test Accuracy of INDIAN PITTA: 100% ( 5/ 5)
# Test Accuracy of INDIAN ROLLER: 100% ( 5/ 5)
# Test Accuracy of INDIGO BUNTING: 100% ( 5/ 5)
# Test Accuracy of   IWI: 100% ( 5/ 5)
# Test Accuracy of JABIRU: 100% ( 5/ 5)
# Test Accuracy of JAVA SPARROW: 100% ( 5/ 5)
# Test Accuracy of  KAGU: 100% ( 5/ 5)
# Test Accuracy of KAKAPO: 100% ( 5/ 5)
# Test Accuracy of KILLDEAR: 100% ( 5/ 5)
# Test Accuracy of KING VULTURE: 100% ( 5/ 5)
# Test Accuracy of  KIWI: 100% ( 5/ 5)
# Test Accuracy of KOOKABURRA: 100% ( 5/ 5)
# Test Accuracy of LARK BUNTING: 100% ( 5/ 5)
# Test Accuracy of LAZULI BUNTING: 100% ( 5/ 5)
# Test Accuracy of LILAC ROLLER: 100% ( 5/ 5)
# Test Accuracy of LONG-EARED OWL: 100% ( 5/ 5)
# Test Accuracy of MAGPIE GOOSE: 80% ( 4/ 5)
# Test Accuracy of MALABAR HORNBILL: 100% ( 5/ 5)
# Test Accuracy of MALACHITE KINGFISHER: 60% ( 3/ 5)
# Test Accuracy of MALAGASY WHITE EYE: 80% ( 4/ 5)
# Test Accuracy of MALEO: 100% ( 5/ 5)
# Test Accuracy of MALLARD DUCK: 100% ( 5/ 5)
# Test Accuracy of MANDRIN DUCK: 100% ( 5/ 5)
# Test Accuracy of MANGROVE CUCKOO: 100% ( 5/ 5)
# Test Accuracy of MARABOU STORK: 100% ( 5/ 5)
# Test Accuracy of MASKED BOOBY: 60% ( 3/ 5)
# Test Accuracy of MASKED LAPWING: 100% ( 5/ 5)
# Test Accuracy of MIKADO  PHEASANT: 100% ( 5/ 5)
# Test Accuracy of MOURNING DOVE: 100% ( 5/ 5)
# Test Accuracy of  MYNA: 100% ( 5/ 5)
# Test Accuracy of NICOBAR PIGEON: 100% ( 5/ 5)
# Test Accuracy of NOISY FRIARBIRD: 100% ( 5/ 5)
# Test Accuracy of NORTHERN CARDINAL: 80% ( 4/ 5)
# Test Accuracy of NORTHERN FLICKER: 80% ( 4/ 5)
# Test Accuracy of NORTHERN FULMAR: 100% ( 5/ 5)
# Test Accuracy of NORTHERN GANNET: 100% ( 5/ 5)
# Test Accuracy of NORTHERN GOSHAWK: 100% ( 5/ 5)
# Test Accuracy of NORTHERN JACANA: 80% ( 4/ 5)
# Test Accuracy of NORTHERN MOCKINGBIRD: 100% ( 5/ 5)
# Test Accuracy of NORTHERN PARULA: 80% ( 4/ 5)
# Test Accuracy of NORTHERN RED BISHOP: 80% ( 4/ 5)
# Test Accuracy of NORTHERN SHOVELER: 100% ( 5/ 5)
# Test Accuracy of OCELLATED TURKEY: 100% ( 5/ 5)
# Test Accuracy of OKINAWA RAIL: 100% ( 5/ 5)
# Test Accuracy of ORANGE BRESTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of ORIENTAL BAY OWL: 100% ( 5/ 5)
# Test Accuracy of OSPREY: 100% ( 5/ 5)
# Test Accuracy of OSTRICH: 100% ( 5/ 5)
# Test Accuracy of OVENBIRD: 100% ( 5/ 5)
# Test Accuracy of OYSTER CATCHER: 100% ( 5/ 5)
# Test Accuracy of PAINTED BUNTING: 100% ( 5/ 5)
# Test Accuracy of PALILA: 100% ( 5/ 5)
# Test Accuracy of PARADISE TANAGER: 100% ( 5/ 5)
# Test Accuracy of PARAKETT  AKULET: 100% ( 5/ 5)
# Test Accuracy of PARUS MAJOR: 100% ( 5/ 5)
# Test Accuracy of PATAGONIAN SIERRA FINCH: 100% ( 5/ 5)
# Test Accuracy of PEACOCK: 100% ( 5/ 5)
# Test Accuracy of PELICAN: 100% ( 5/ 5)
# Test Accuracy of PEREGRINE FALCON: 80% ( 4/ 5)
# Test Accuracy of PHILIPPINE EAGLE: 100% ( 5/ 5)
# Test Accuracy of PINK ROBIN: 100% ( 5/ 5)
# Test Accuracy of POMARINE JAEGER: 80% ( 4/ 5)
# Test Accuracy of PUFFIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE FINCH: 100% ( 5/ 5)
# Test Accuracy of PURPLE GALLINULE: 100% ( 5/ 5)
# Test Accuracy of PURPLE MARTIN: 100% ( 5/ 5)
# Test Accuracy of PURPLE SWAMPHEN: 80% ( 4/ 5)
# Test Accuracy of PYGMY KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of QUETZAL: 100% ( 5/ 5)
# Test Accuracy of RAINBOW LORIKEET: 100% ( 5/ 5)
# Test Accuracy of RAZORBILL: 100% ( 5/ 5)
# Test Accuracy of RED BEARDED BEE EATER: 100% ( 5/ 5)
# Test Accuracy of RED BELLIED PITTA: 100% ( 5/ 5)
# Test Accuracy of RED BROWED FINCH: 100% ( 5/ 5)
# Test Accuracy of RED FACED CORMORANT: 100% ( 5/ 5)
# Test Accuracy of RED FACED WARBLER: 100% ( 5/ 5)
# Test Accuracy of RED FODY: 100% ( 5/ 5)
# Test Accuracy of RED HEADED DUCK: 100% ( 5/ 5)
# Test Accuracy of RED HEADED WOODPECKER: 100% ( 5/ 5)
# Test Accuracy of RED HONEY CREEPER: 100% ( 5/ 5)
# Test Accuracy of RED NAPED TROGON: 100% ( 5/ 5)
# Test Accuracy of RED TAILED HAWK: 100% ( 5/ 5)
# Test Accuracy of RED TAILED THRUSH: 80% ( 4/ 5)
# Test Accuracy of RED WINGED BLACKBIRD: 80% ( 4/ 5)
# Test Accuracy of RED WISKERED BULBUL: 100% ( 5/ 5)
# Test Accuracy of REGENT BOWERBIRD: 100% ( 5/ 5)
# Test Accuracy of RING-NECKED PHEASANT: 100% ( 5/ 5)
# Test Accuracy of ROADRUNNER: 100% ( 5/ 5)
# Test Accuracy of ROBIN: 80% ( 4/ 5)
# Test Accuracy of ROCK DOVE: 100% ( 5/ 5)
# Test Accuracy of ROSY FACED LOVEBIRD: 100% ( 5/ 5)
# Test Accuracy of ROUGH LEG BUZZARD: 20% ( 1/ 5)
# Test Accuracy of ROYAL FLYCATCHER: 100% ( 5/ 5)
# Test Accuracy of RUBY THROATED HUMMINGBIRD: 60% ( 3/ 5)
# Test Accuracy of RUDY KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of RUFOUS KINGFISHER: 80% ( 4/ 5)
# Test Accuracy of RUFUOS MOTMOT: 100% ( 5/ 5)
# Test Accuracy of SAMATRAN THRUSH: 60% ( 3/ 5)
# Test Accuracy of SAND MARTIN: 100% ( 5/ 5)
# Test Accuracy of SANDHILL CRANE: 100% ( 5/ 5)
# Test Accuracy of SATYR TRAGOPAN: 100% ( 5/ 5)
# Test Accuracy of SCARLET CROWNED FRUIT DOVE: 100% ( 5/ 5)
# Test Accuracy of SCARLET IBIS: 100% ( 5/ 5)
# Test Accuracy of SCARLET MACAW: 100% ( 5/ 5)
# Test Accuracy of SCARLET TANAGER: 100% ( 5/ 5)
# Test Accuracy of SHOEBILL: 100% ( 5/ 5)
# Test Accuracy of SHORT BILLED DOWITCHER: 100% ( 5/ 5)
# Test Accuracy of SMITHS LONGSPUR: 60% ( 3/ 5)
# Test Accuracy of SNOWY EGRET: 100% ( 5/ 5)
# Test Accuracy of SNOWY OWL: 100% ( 5/ 5)
# Test Accuracy of  SORA: 80% ( 4/ 5)
# Test Accuracy of SPANGLED COTINGA: 100% ( 5/ 5)
# Test Accuracy of SPLENDID WREN: 100% ( 5/ 5)
# Test Accuracy of SPOON BILED SANDPIPER: 100% ( 5/ 5)
# Test Accuracy of SPOONBILL: 100% ( 5/ 5)
# Test Accuracy of SPOTTED CATBIRD: 100% ( 5/ 5)
# Test Accuracy of SRI LANKA BLUE MAGPIE: 100% ( 5/ 5)
# Test Accuracy of STEAMER DUCK: 100% ( 5/ 5)
# Test Accuracy of STORK BILLED KINGFISHER: 100% ( 5/ 5)
# Test Accuracy of STRAWBERRY FINCH: 100% ( 5/ 5)
# Test Accuracy of STRIPED OWL: 100% ( 5/ 5)
# Test Accuracy of STRIPPED MANAKIN: 100% ( 5/ 5)
# Test Accuracy of STRIPPED SWALLOW: 100% ( 5/ 5)
# Test Accuracy of SUPERB STARLING: 100% ( 5/ 5)
# Test Accuracy of SWINHOES PHEASANT: 100% ( 5/ 5)
# Test Accuracy of TAIWAN MAGPIE: 100% ( 5/ 5)
# Test Accuracy of TAKAHE: 80% ( 4/ 5)
# Test Accuracy of TASMANIAN HEN: 100% ( 5/ 5)
# Test Accuracy of TEAL DUCK: 100% ( 5/ 5)
# Test Accuracy of TIT MOUSE: 100% ( 5/ 5)
# Test Accuracy of TOUCHAN: 100% ( 5/ 5)
# Test Accuracy of TOWNSENDS WARBLER: 40% ( 2/ 5)
# Test Accuracy of TREE SWALLOW: 80% ( 4/ 5)
# Test Accuracy of TROPICAL KINGBIRD: 80% ( 4/ 5)
# Test Accuracy of TRUMPTER SWAN: 100% ( 5/ 5)
# Test Accuracy of TURKEY VULTURE: 100% ( 5/ 5)
# Test Accuracy of TURQUOISE MOTMOT: 100% ( 5/ 5)
# Test Accuracy of UMBRELLA BIRD: 100% ( 5/ 5)
# Test Accuracy of VARIED THRUSH: 100% ( 5/ 5)
# Test Accuracy of VENEZUELIAN TROUPIAL: 100% ( 5/ 5)
# Test Accuracy of VERMILION FLYCATHER: 100% ( 5/ 5)
# Test Accuracy of VICTORIA CROWNED PIGEON: 100% ( 5/ 5)
# Test Accuracy of VIOLET GREEN SWALLOW: 100% ( 5/ 5)
# Test Accuracy of VULTURINE GUINEAFOWL: 60% ( 3/ 5)
# Test Accuracy of WALL CREAPER: 80% ( 4/ 5)
# Test Accuracy of WATTLED CURASSOW: 100% ( 5/ 5)
# Test Accuracy of WATTLED LAPWING: 80% ( 4/ 5)
# Test Accuracy of WHIMBREL: 100% ( 5/ 5)
# Test Accuracy of WHITE BROWED CRAKE: 100% ( 5/ 5)
# Test Accuracy of WHITE CHEEKED TURACO: 60% ( 3/ 5)
# Test Accuracy of WHITE NECKED RAVEN: 100% ( 5/ 5)
# Test Accuracy of WHITE TAILED TROPIC: 100% ( 5/ 5)
# Test Accuracy of WHITE THROATED BEE EATER: 60% ( 3/ 5)
# Test Accuracy of WILD TURKEY: 100% ( 5/ 5)
# Test Accuracy of WILSONS BIRD OF PARADISE: 100% ( 5/ 5)
# Test Accuracy of WOOD DUCK: 100% ( 5/ 5)
# Test Accuracy of YELLOW BELLIED FLOWERPECKER: 80% ( 4/ 5)
# Test Accuracy of YELLOW CACIQUE: 100% ( 5/ 5)
# Test Accuracy of YELLOW HEADED BLACKBIRD: 100% ( 5/ 5)
# Test Loss: 0.228674
#
#
# Test Accuracy (Overall): 94% (1653/1750)

# %% [markdown]
# > ResNet 152

# %% [markdown]
# # Conclusion

# %% [markdown]
# With same train, valid and test datasets, and same loss function and criterion, VGG-19 model gives only 1% accuracy, but ResNet-18 gives 93% accuracy. Therefore, the structure of ResNet fits this bird species datasets better. Further exploration of ResNet50 gives 91% accuracy.

# %% [markdown]
# The model tuning will based comparison of difference between VGG model and ResNet model. Besides, all three pre-trained models shows overfitting issue, with valid loss increasing. Data augmentation may applied in later experiments.
